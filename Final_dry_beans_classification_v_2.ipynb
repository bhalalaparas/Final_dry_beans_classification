# %%
# !ls
# Out:
# Dry_Bean_Dataset.xlsx  sample_data

# %%
import pandas as pd # Import the pandas library
import matplotlib.pyplot as plt # Import the matplotlib for data visulation
import seaborn as sns
import numpy as np

# %%
# Use the pands `read_excel()` method to read an Excel file named "Dry_Bean_Dataset.xlsx" and read the data from the sheet named with "Dry_Beans_Dataset"

df = pd.read_excel('Dry_Bean_Dataset.xlsx', sheet_name='Dry_Beans_Dataset') # Store the resulting data in a pandas DataFrame object named `df`

# %% [markdown]
# # New Section

# %%
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653248  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
# Use the pandas `head()` method to display the first 5 rows of data from the DataFrame `df`

df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %%
# Count the number of occurrences of each class
class_counts = df['Class'].value_counts()

# %%
class_counts
# Out:
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: Class, dtype: int64

# %%
# Plot the result in a bar graph
class_counts.plot(kind='bar')
plt.title('Class Counts')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
# Use the pandas `head()` method to display the first 5 rows of data from the DataFrame `df`

df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %%
#panad  df.info() is a method that returns information about the DataFrame 'df'
# This method provides a concise summary of the DataFrame 'df'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
# for pandas the corr method to find the correlation between the data
df.corr()
# Out:
# <ipython-input-11-8476bb6d48c8>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966722         0.931834         0.951602
# Perimeter        0.966722   1.000000         0.977338         0.913179
# MajorAxisLength  0.931834   0.977338         1.000000         0.826052
# MinorAxisLength  0.951602   0.913179         0.826052         1.000000
# AspectRation     0.241735   0.385276         0.550335        -0.009161
# Eccentricity     0.267481   0.391066         0.541972         0.019574
# ConvexArea       0.999939   0.967689         0.932607         0.951339
# EquivDiameter    0.984968   0.991380         0.961733         0.948539
# Extent           0.054345  -0.021160        -0.078062         0.145957
# Solidity        -0.196585  -0.303970        -0.284302        -0.155831
# roundness       -0.357530  -0.547647        -0.596358        -0.210344
# Compactness     -0.268067  -0.406857        -0.568377        -0.015066
# ShapeFactor1    -0.847958  -0.864623        -0.773609        -0.947204
# ShapeFactor2    -0.639291  -0.767592        -0.859238        -0.471347
# ShapeFactor3    -0.272145  -0.408435        -0.568185        -0.019326
# ShapeFactor4    -0.355721  -0.429310        -0.482527        -0.263749
#
#                  AspectRation  Eccentricity  ConvexArea  EquivDiameter  \
# Area                 0.241735      0.267481    0.999939       0.984968
# Perimeter            0.385276      0.391066    0.967689       0.991380
# MajorAxisLength      0.550335      0.541972    0.932607       0.961733
# MinorAxisLength     -0.009161      0.019574    0.951339       0.948539
# AspectRation         1.000000      0.924293    0.243301       0.303647
# Eccentricity         0.924293      1.000000    0.269255       0.318667
# ConvexArea           0.243301      0.269255    1.000000       0.985226
# EquivDiameter        0.303647      0.318667    0.985226       1.000000
# Extent              -0.370184     -0.319362    0.052564       0.028383
# Solidity            -0.267754     -0.297592   -0.206191      -0.231648
# roundness           -0.766979     -0.722272   -0.362083      -0.435945
# Compactness         -0.987687     -0.970313   -0.269922      -0.327650
# ShapeFactor1         0.024593      0.019920   -0.847950      -0.892741
# ShapeFactor2        -0.837841     -0.860141   -0.640862      -0.713069
# ShapeFactor3        -0.978592     -0.981058   -0.274024      -0.330389
# ShapeFactor4        -0.449264     -0.449354   -0.362049      -0.392512
#
#                    Extent  Solidity  roundness  Compactness  ShapeFactor1  \
# Area             0.054345 -0.196585  -0.357530    -0.268067     -0.847958
# Perimeter       -0.021160 -0.303970  -0.547647    -0.406857     -0.864623
# MajorAxisLength -0.078062 -0.284302  -0.596358    -0.568377     -0.773609
# MinorAxisLength  0.145957 -0.155831  -0.210344    -0.015066     -0.947204
# AspectRation    -0.370184 -0.267754  -0.766979    -0.987687      0.024593
# Eccentricity    -0.319362 -0.297592  -0.722272    -0.970313      0.019920
# ConvexArea       0.052564 -0.206191  -0.362083    -0.269922     -0.847950
# EquivDiameter    0.028383 -0.231648  -0.435945    -0.327650     -0.892741
# Extent           1.000000  0.191389   0.344411     0.354212     -0.141616
# Solidity         0.191389  1.000000   0.607150     0.303766      0.153388
# roundness        0.344411  0.607150   1.000000     0.768086      0.230273
# Compactness      0.354212  0.303766   0.768086     1.000000     -0.009394
# ShapeFactor1    -0.141616  0.153388   0.230273    -0.009394      1.000000
# ShapeFactor2     0.237956  0.343559   0.782824     0.868939      0.469197
# ShapeFactor3     0.347624  0.307662   0.763126     0.998686     -0.008320
# ShapeFactor4     0.148502  0.702163   0.472149     0.484436      0.248619
#
#                  ShapeFactor2  ShapeFactor3  ShapeFactor4
# Area                -0.639291     -0.272145     -0.355721
# Perimeter           -0.767592     -0.408435     -0.429310
# MajorAxisLength     -0.859238     -0.568185     -0.482527
# MinorAxisLength     -0.471347     -0.019326     -0.263749
# AspectRation        -0.837841     -0.978592     -0.449264
# Eccentricity        -0.860141     -0.981058     -0.449354
# ConvexArea          -0.640862     -0.274024     -0.362049
# EquivDiameter       -0.713069     -0.330389     -0.392512
# Extent               0.237956      0.347624      0.148502
# Solidity             0.343559      0.307662      0.702163
# roundness            0.782824      0.763126      0.472149
# Compactness          0.868939      0.998686      0.484436
# ShapeFactor1         0.469197     -0.008320      0.248619
# ShapeFactor2         1.000000      0.872971      0.529932
# ShapeFactor3         0.872971      1.000000      0.484274
# ShapeFactor4         0.529932      0.484274      1.000000

# %%
# %matplotlib inline

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-13-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
#plt.show()

# %%
#check the null values in this dataset
df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,cmap='viridis',linewidths=.5)
# Out:
# <ipython-input-16-e739994d4f4e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='viridis',linewidths=.5)
# <Axes: >

# %%
# separate the features and target variable

Y = df['Class'] # Target dataset
X = df.drop(['Class'], axis=1) # Input Dataset feature

# %%
Y
# Out:
# 0           SEKER
# 1           SEKER
# 2           SEKER
# 3           SEKER
# 4           SEKER
#            ...
# 13606    DERMASON
# 13607    DERMASON
# 13608    DERMASON
# 13609    DERMASON
# 13610    DERMASON
# Name: Class, Length: 13611, dtype: object

# %%
X
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653248  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
new_y_test =y_test

# %%
x_train
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 4471   71929   1036.972       392.325289       234.905763      1.670139
# 9391   47705    824.388       311.904180       195.594415      1.594648
# 9576   48903    849.167       324.353419       194.159800      1.670549
# 6280   52108    911.035       381.863659       174.458080      2.188856
# 4798   76273   1085.578       431.624614       226.689336      1.904036
# ...      ...        ...              ...              ...           ...
# 12289  33693    672.456       242.009959       177.930302      1.360139
# 3993   63139    971.167       378.936577       214.342829      1.767899
# 5553   38891    791.343       319.499996       156.869619      2.036723
# 13552  41499    757.035       284.298362       186.453775      1.524766
# 1272   40838    731.101       242.897155       214.415204      1.132836
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 4471       0.800934       73002     302.626580  0.695672  0.985302   0.840581
# 9391       0.778941       48235     246.454646  0.795800  0.989012   0.882085
# 9576       0.801044       49534     249.530025  0.684686  0.987261   0.852235
# 6280       0.889539       52662     257.577107  0.692373  0.989480   0.788940
# 4798       0.850979       77276     311.630871  0.831404  0.987021   0.813315
# ...             ...         ...            ...       ...       ...        ...
# 12289      0.677830       34008     207.121365  0.777842  0.990737   0.936315
# 3993       0.824650       64207     283.533193  0.714630  0.983366   0.841240
# 5553       0.871168       39651     222.525412  0.650025  0.980833   0.780422
# 13552      0.754901       41899     229.865543  0.808569  0.990453   0.909946
# 1272       0.469860       41208     228.027535  0.790423  0.991021   0.960107
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 4471      0.771366      0.005454      0.001191      0.595006      0.993743
# 9391      0.790161      0.006538      0.001572      0.624355      0.995626
# 9576      0.769315      0.006633      0.001433      0.591846      0.988707
# 6280      0.674526      0.007328      0.000936      0.454986      0.995899
# 4798      0.721995      0.005659      0.000949      0.521277      0.992530
# ...            ...           ...           ...           ...           ...
# 12289     0.855838      0.007183      0.002377      0.732459      0.996246
# 3993      0.748234      0.006002      0.001160      0.559854      0.989766
# 5553      0.696480      0.008215      0.001192      0.485085      0.987983
# 13552     0.808536      0.006851      0.001806      0.653731      0.996787
# 1272      0.938782      0.005948      0.002850      0.881312      0.998382
#
# [10888 rows x 16 columns]

# %%
# for checking the accuracy of model
from sklearn.metrics import accuracy_score, classification_report

# %%
# for labeling encode
from sklearn.preprocessing import LabelEncoder

# %%
# Initialize LabelEncoder object
le = LabelEncoder()

# Fit and transform multiclass_data
Y_train = le.fit_transform(y_train)
Y_test = le.fit_transform(y_test)

# %% [markdown]
# Data Scaling

# %%
# perform feature scaling on the training and testing sets
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.fit_transform(x_test)

# %%
#inital store accuracy
initial_All_Model_Acc = {}
inital_All_Model_Training_Accuracy={}

# %%
# import the necessary libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ANN

# %%
# create a sequential model object
model = Sequential()   

# add a dense layer with 100 units, ReLU activation function, and input dimension of 16 to the model
model.add(Dense(100,activation='relu',input_dim=16))

# create a sequential model object
model.add(Dense(50,activation='relu'))

# create a sequential model object
model.add(Dense(7,activation='softmax'))

# %%
#Complie the model
model.compile(loss='sparse_categorical_crossentropy',  # Use sparse categorical cross-entropy as the loss function
              optimizer=Adam(learning_rate=0.001),  # Use Adam optimizer with learning rate of 0.001
              metrics=['accuracy'])  # Track accuracy as the evaluation metric

# %%
# Train the ANN model on the training data for 50 epochs, with a 32 batch size
# Print the training log information for each epoch (verbose=2)
history = model.fit(X_train, Y_train, epochs=50, batch_size=32, verbose=2,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/50
# 341/341 - 7s - loss: 0.4676 - accuracy: 0.8529 - val_loss: 0.2328 - val_accuracy: 0.9148 - 7s/epoch - 20ms/step
# Epoch 2/50
# 341/341 - 1s - loss: 0.2140 - accuracy: 0.9248 - val_loss: 0.2070 - val_accuracy: 0.9221 - 942ms/epoch - 3ms/step
# Epoch 3/50
# 341/341 - 1s - loss: 0.2051 - accuracy: 0.9241 - val_loss: 0.2065 - val_accuracy: 0.9196 - 1s/epoch - 3ms/step
# Epoch 4/50
# 341/341 - 1s - loss: 0.1950 - accuracy: 0.9287 - val_loss: 0.2094 - val_accuracy: 0.9240 - 963ms/epoch - 3ms/step
# Epoch 5/50
# 341/341 - 1s - loss: 0.1954 - accuracy: 0.9275 - val_loss: 0.1928 - val_accuracy: 0.9240 - 941ms/epoch - 3ms/step
# Epoch 6/50
# 341/341 - 1s - loss: 0.1910 - accuracy: 0.9304 - val_loss: 0.1906 - val_accuracy: 0.9273 - 919ms/epoch - 3ms/step
# Epoch 7/50
# 341/341 - 1s - loss: 0.1881 - accuracy: 0.9297 - val_loss: 0.1949 - val_accuracy: 0.9262 - 958ms/epoch - 3ms/step
# Epoch 8/50
# 341/341 - 1s - loss: 0.1862 - accuracy: 0.9324 - val_loss: 0.1881 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 9/50
# 341/341 - 1s - loss: 0.1855 - accuracy: 0.9296 - val_loss: 0.1879 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 10/50
# 341/341 - 1s - loss: 0.1839 - accuracy: 0.9310 - val_loss: 0.1936 - val_accuracy: 0.9266 - 959ms/epoch - 3ms/step
# Epoch 11/50
# 341/341 - 1s - loss: 0.1816 - accuracy: 0.9330 - val_loss: 0.1975 - val_accuracy: 0.9258 - 963ms/epoch - 3ms/step
# Epoch 12/50
# 341/341 - 1s - loss: 0.1803 - accuracy: 0.9324 - val_loss: 0.1942 - val_accuracy: 0.9236 - 924ms/epoch - 3ms/step
# Epoch 13/50
# 341/341 - 1s - loss: 0.1790 - accuracy: 0.9339 - val_loss: 0.1996 - val_accuracy: 0.9247 - 928ms/epoch - 3ms/step
# Epoch 14/50
# 341/341 - 1s - loss: 0.1786 - accuracy: 0.9324 - val_loss: 0.1947 - val_accuracy: 0.9284 - 957ms/epoch - 3ms/step
# Epoch 15/50
# 341/341 - 1s - loss: 0.1764 - accuracy: 0.9336 - val_loss: 0.1885 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 16/50
# 341/341 - 1s - loss: 0.1759 - accuracy: 0.9342 - val_loss: 0.1927 - val_accuracy: 0.9299 - 942ms/epoch - 3ms/step
# Epoch 17/50
# 341/341 - 1s - loss: 0.1744 - accuracy: 0.9330 - val_loss: 0.1886 - val_accuracy: 0.9273 - 1s/epoch - 4ms/step
# Epoch 18/50
# 341/341 - 1s - loss: 0.1747 - accuracy: 0.9331 - val_loss: 0.2072 - val_accuracy: 0.9258 - 1s/epoch - 4ms/step
# Epoch 19/50
# 341/341 - 2s - loss: 0.1737 - accuracy: 0.9343 - val_loss: 0.1927 - val_accuracy: 0.9254 - 2s/epoch - 6ms/step
# Epoch 20/50
# 341/341 - 1s - loss: 0.1728 - accuracy: 0.9349 - val_loss: 0.1954 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 21/50
# 341/341 - 1s - loss: 0.1721 - accuracy: 0.9361 - val_loss: 0.1928 - val_accuracy: 0.9251 - 965ms/epoch - 3ms/step
# Epoch 22/50
# 341/341 - 1s - loss: 0.1712 - accuracy: 0.9364 - val_loss: 0.1881 - val_accuracy: 0.9313 - 961ms/epoch - 3ms/step
# Epoch 23/50
# 341/341 - 1s - loss: 0.1708 - accuracy: 0.9365 - val_loss: 0.1982 - val_accuracy: 0.9273 - 934ms/epoch - 3ms/step
# Epoch 24/50
# 341/341 - 1s - loss: 0.1702 - accuracy: 0.9352 - val_loss: 0.1928 - val_accuracy: 0.9273 - 936ms/epoch - 3ms/step
# Epoch 25/50
# 341/341 - 1s - loss: 0.1684 - accuracy: 0.9367 - val_loss: 0.1937 - val_accuracy: 0.9254 - 938ms/epoch - 3ms/step
# Epoch 26/50
# 341/341 - 1s - loss: 0.1685 - accuracy: 0.9380 - val_loss: 0.1854 - val_accuracy: 0.9310 - 950ms/epoch - 3ms/step
# Epoch 27/50
# 341/341 - 1s - loss: 0.1671 - accuracy: 0.9368 - val_loss: 0.1932 - val_accuracy: 0.9284 - 955ms/epoch - 3ms/step
# Epoch 28/50
# 341/341 - 1s - loss: 0.1662 - accuracy: 0.9370 - val_loss: 0.1908 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 29/50
# 341/341 - 1s - loss: 0.1662 - accuracy: 0.9381 - val_loss: 0.1919 - val_accuracy: 0.9299 - 936ms/epoch - 3ms/step
# Epoch 30/50
# 341/341 - 1s - loss: 0.1671 - accuracy: 0.9372 - val_loss: 0.1903 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 31/50
# 341/341 - 1s - loss: 0.1648 - accuracy: 0.9375 - val_loss: 0.1954 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 32/50
# 341/341 - 1s - loss: 0.1656 - accuracy: 0.9368 - val_loss: 0.1944 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 33/50
# 341/341 - 1s - loss: 0.1624 - accuracy: 0.9375 - val_loss: 0.1846 - val_accuracy: 0.9291 - 956ms/epoch - 3ms/step
# Epoch 34/50
# 341/341 - 1s - loss: 0.1627 - accuracy: 0.9391 - val_loss: 0.1866 - val_accuracy: 0.9299 - 953ms/epoch - 3ms/step
# Epoch 35/50
# 341/341 - 1s - loss: 0.1614 - accuracy: 0.9375 - val_loss: 0.1820 - val_accuracy: 0.9299 - 945ms/epoch - 3ms/step
# Epoch 36/50
# 341/341 - 1s - loss: 0.1609 - accuracy: 0.9389 - val_loss: 0.1908 - val_accuracy: 0.9295 - 921ms/epoch - 3ms/step
# Epoch 37/50
# 341/341 - 1s - loss: 0.1606 - accuracy: 0.9419 - val_loss: 0.1875 - val_accuracy: 0.9280 - 943ms/epoch - 3ms/step
# Epoch 38/50
# 341/341 - 1s - loss: 0.1601 - accuracy: 0.9397 - val_loss: 0.1906 - val_accuracy: 0.9277 - 959ms/epoch - 3ms/step
# Epoch 39/50
# 341/341 - 1s - loss: 0.1584 - accuracy: 0.9397 - val_loss: 0.1912 - val_accuracy: 0.9277 - 935ms/epoch - 3ms/step
# Epoch 40/50
# 341/341 - 1s - loss: 0.1593 - accuracy: 0.9394 - val_loss: 0.1872 - val_accuracy: 0.9269 - 925ms/epoch - 3ms/step
# Epoch 41/50
# 341/341 - 1s - loss: 0.1605 - accuracy: 0.9381 - val_loss: 0.1859 - val_accuracy: 0.9310 - 921ms/epoch - 3ms/step
# Epoch 42/50
# 341/341 - 1s - loss: 0.1601 - accuracy: 0.9375 - val_loss: 0.1909 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 43/50
# 341/341 - 1s - loss: 0.1586 - accuracy: 0.9389 - val_loss: 0.1934 - val_accuracy: 0.9310 - 1s/epoch - 4ms/step
# Epoch 44/50
# 341/341 - 1s - loss: 0.1560 - accuracy: 0.9414 - val_loss: 0.1878 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 45/50
# 341/341 - 1s - loss: 0.1561 - accuracy: 0.9407 - val_loss: 0.1901 - val_accuracy: 0.9332 - 966ms/epoch - 3ms/step
# Epoch 46/50
# 341/341 - 1s - loss: 0.1570 - accuracy: 0.9398 - val_loss: 0.1886 - val_accuracy: 0.9346 - 924ms/epoch - 3ms/step
# Epoch 47/50
# 341/341 - 1s - loss: 0.1561 - accuracy: 0.9401 - val_loss: 0.1954 - val_accuracy: 0.9273 - 923ms/epoch - 3ms/step
# Epoch 48/50
# 341/341 - 1s - loss: 0.1562 - accuracy: 0.9421 - val_loss: 0.2018 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 49/50
# 341/341 - 1s - loss: 0.1555 - accuracy: 0.9417 - val_loss: 0.1890 - val_accuracy: 0.9313 - 1s/epoch - 3ms/step
# Epoch 50/50
# 341/341 - 1s - loss: 0.1532 - accuracy: 0.9422 - val_loss: 0.1909 - val_accuracy: 0.9284 - 933ms/epoch - 3ms/step

# %%
# Use the trained model to make predictions on the testing dataset and calculate the accuracy of testing dataset
y_pred = model.predict(X_test)  # Get predicted class probabilities of the testing dataset
Y_pred_test = y_pred.argmax(axis=-1) # Convert above probabilities to class labels
test_Accuracy = accuracy_score(Y_test,Y_pred_test)  # Calculate accuracy of predicted labels compared to actual labels
print("Testing ANN Accuracy: ",test_Accuracy)  # Print the testing accuracy

# Use the trained model to make predictions on the training dataset and calculate the accuracy of training dataset
y_pred = model.predict(X_train)   # Get predicted class probabilities of the training dataset
Y_pred = y_pred.argmax(axis=-1)   # Convert above probabilities to class labels
train_Accuracy = accuracy_score(Y_train,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Training ANN Accuracy: ",train_Accuracy)  # Print the testing accuracy

# Store the testing accuracy and training accuracy of the model in separate dictionaries
initial_All_Model_Acc['Ann']= test_Accuracy*100    # Store testing accuracy
inital_All_Model_Training_Accuracy['Ann']= train_Accuracy*100   # Store training accuracy
# Out:
# 86/86 [==============================] - 0s 1ms/step
# Testing ANN Accuracy:  0.9283878075651855
# 341/341 [==============================] - 0s 1ms/step
# Training ANN Accuracy:  0.9431484202792064

# %% [markdown]
# Visualizing model performance and classification report

# %%
# this graph is for ANN testing 
from sklearn import metrics
# label_names = ['Seker', 'Barbunya', 'Bombay', 'Cali', 'Dermosan', 'Horoz','Sira']
label_names = le.inverse_transform(np.unique(Y_test))
cm_cnn = metrics.confusion_matrix(Y_test, Y_pred_test)
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(cm_cnn, annot=True, fmt='g', xticklabels=label_names, yticklabels=label_names)
ax.set(ylabel="True Label", xlabel="Predicted Label", title="ANN Artifical Neural Network Confusion Matrix - Testing")
plt.show()

# %%
# this graph is for ANN training 
from sklearn import metrics
# label_names = ['Seker', 'Barbunya', 'Bombay', 'Cali', 'Dermosan', 'Horoz','Sira']
label_names = le.inverse_transform(np.unique(Y_test))
cm_cnn = metrics.confusion_matrix(Y_train, Y_pred)
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(cm_cnn, annot=True, fmt='g', xticklabels=label_names, yticklabels=label_names)
ax.set(ylabel="True Label", xlabel="Predicted Label", title="ANN Artifical Neural Network Confusion Matrix - Training")
plt.show()

# %%
# Decode the numerical values back to categorical labels
decoded_labels = le.inverse_transform([Y_pred[0]])
print(decoded_labels)
# Out:
# ['CALI']

# %%
# graph shown btween accuracy vs validation accuracy
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Testing Accuracy')
plt.xlim(0, 50) # Set the x axis limits
plt.ylim(0.8, 0.98) # Set the y axis limits
plt.title('Accuracy over Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Plot the training accuracy vs. epoch

plt.plot(history.history['accuracy'],label='Training Accuracy')

# Set as a x-axis limits to (0, 50) and y-axis limits to (0.8, 0.98)
plt.xlim(0, 50)
plt.ylim(0.8, 0.98)

# Set the title of the plot graph to "Accuracy Graph" and the x- and y-axis labels
plt.title('Accuracy Graph')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
from keras.utils import plot_model # Import the plot_model function from Keras utils
plot_model(model, show_shapes=True) # # Generate a visualization of the model architecture with input/output shapes

# %%
model.summary() # model summary
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               1700
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 7)                 357
#
# =================================================================
# Total params: 7,107
# Trainable params: 7,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Predict and Decode the numerical values back to categorical labels
decoded_predicted_labels_logistic = le.inverse_transform(model.predict(np.array(X_test)).argmax(axis=-1))
print(decoded_predicted_labels_logistic)


#make a instance id from testing datasets
instance_ids = x_test.index
# Out:
# 86/86 [==============================] - 0s 2ms/step
# ['DERMASON' 'SIRA' 'CALI' ... 'SEKER' 'DERMASON' 'DERMASON']

# %%
# create a pandas dataframe with the instance IDs and predicted labels'

df_csv = pd.DataFrame({'Instance ID': instance_ids, 'Predicted Label': decoded_predicted_labels_logistic})

# save the dataframe to a .csv file
df_csv.to_csv('ANN_Predictions.csv', index=False)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Initialize a Logistic Regression model
logreg = LogisticRegression()

# Train the model on the training data
logreg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Make predictions on the testing data and Calculate the accuracy of the Logistic Regression model

# Predict on the testing data
y_pred_test = logreg.predict(X_test) # Predict on the testing data
test_Accuracy = accuracy_score(Y_test, y_pred_test) # Calculate the accuracy of the model on testing data
print("Logistic Testing Accuracy:", test_Accuracy) 

# Predict on the training data
Y_pred = logreg.predict(X_train) # Predict on the training data
train_Accuracy = accuracy_score(Y_train, Y_pred) # Calculate the accuracy of the model on training data
print("Logistic Training Accuracy:", train_Accuracy)

initial_All_Model_Acc['Logistic']= test_Accuracy*100   # Store the testing accuracy in a dictionary
inital_All_Model_Training_Accuracy['Logistic']= train_Accuracy*100  # Store the training accuracy in a dictionary
# Out:
# Logistic Testing Accuracy: 0.9225119353654058
# Logistic Training Accuracy: 0.9251469507714916

# %%
# this graph is Logistic Regression Confusion Matrix for testing 
from sklearn import metrics
# label_names = ['Seker', 'Barbunya', 'Bombay', 'Cali', 'Dermosan', 'Horoz','Sira']
label_names = le.inverse_transform(np.unique(Y_test))
cm_cnn = metrics.confusion_matrix(Y_test, y_pred_test)
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(cm_cnn, annot=True, fmt='g', xticklabels=label_names, yticklabels=label_names)
ax.set(ylabel="True Label", xlabel="Predicted Label", title="Logistic Regression Confusion Matrix - Testing")
plt.show()

# %%
# this graph is Logistic Regression Confusion Matrix for training 
from sklearn import metrics
# label_names = ['Seker', 'Barbunya', 'Bombay', 'Cali', 'Dermosan', 'Horoz','Sira']
label_names = le.inverse_transform(np.unique(Y_train))
cm_cnn = metrics.confusion_matrix(Y_train, Y_pred)
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(cm_cnn, annot=True, fmt='g', xticklabels=label_names, yticklabels=label_names)
ax.set(ylabel="True Label", xlabel="Predicted Label", title="Logistic Regression Confusion Matrix - Training")
plt.show()

# %%
# Predict and Decode the numerical values back to categorical labels
decoded_predicted_labels = le.inverse_transform(model.predict(np.array(X_test)).argmax(axis=-1))
print(decoded_predicted_labels)


#make a instance id from testing datasets
instance_ids = x_test.index
# Out:
# 86/86 [==============================] - 0s 1ms/step
# ['DERMASON' 'SIRA' 'CALI' ... 'SEKER' 'DERMASON' 'DERMASON']

# %%
# create a pandas dataframe with the instance IDs and predicted labels'

df_csv = pd.DataFrame({'Instance ID': instance_ids, 'Predicted Label': decoded_predicted_labels})

# save the dataframe to a .csv file
df_csv.to_csv('Logistic_Predictions.csv', index=False)

# %% [markdown]
# KNN classification

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Create a k-NN classifier with k=3
knn = KNeighborsClassifier(n_neighbors=3)

# %%
# Train the classifier
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Make predictions on the testing data and Calculate the accuracy of the KNN model

# Use the KNN model to predict the output of the testing dataset (X_test)
y_pred = knn.predict(X_test)
test_Accuracy = accuracy_score(Y_test, y_pred) # Calculate the accuracy of the predicted output (y_pred) against the true output (Y_test)
print("KNN Testing Accuracy:", test_Accuracy)

# Use the KNN model to predict the output of the training dataset (X_train)
y_pred = knn.predict(X_train)
train_Accuracy = accuracy_score(Y_train, y_pred) # Calculate the accuracy of the predicted output (y_pred) against the true output (Y_train)
print("KNN Training Accuracy:", train_Accuracy)

initial_All_Model_Acc['KNN']= test_Accuracy*100    # Store the testing accuracy in a dictionary
inital_All_Model_Training_Accuracy['KNN']= train_Accuracy*100  # Store the training accuracy in a dictionary
# Out:
# KNN Testing Accuracy: 0.922879177377892
# KNN Training Accuracy: 0.950955180014695

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Create the decision tree classifier object
clf = DecisionTreeClassifier()

# %%
# Train the classifier on the training data
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Make predictions on the testing data and Calculate the accuracy of the Decision Tree model

# Predict the class labels of test instances
y_pred = clf.predict(X_test)
test_Accuracy = accuracy_score(Y_test, y_pred)  # Calculate the accuracy of the model on test data
print("Decision Tree Testing Accuracy:", test_Accuracy)

# Predict the class labels of train instances
y_pred = clf.predict(X_train)
train_Accuracy = accuracy_score(Y_train, y_pred)  # Calculate the accuracy of the model on train data
print("Decision Tree Training Accuracy:", train_Accuracy)

initial_All_Model_Acc['decision_Tree']= test_Accuracy*100  # Save the testing accuracy in a dictionary with key 'decision_Tree'
inital_All_Model_Training_Accuracy['decision_Tree']= train_Accuracy*100   # Save the training accuracy in a dictionary with key 'decision_Tree'
# Out:
# Decision Tree Testing Accuracy: 0.897172236503856
# Decision Tree Training Accuracy: 1.0

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Create the random forest classifier object
random_model = RandomForestClassifier(n_estimators=500, random_state = 42)

# %%
# Fit the model to the training data
random_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(n_estimators=500, random_state=42)

# %%
# Make predictions on the testing data and Calculate the accuracy of the Random Forest model

y_pred = random_model.predict(X_test) # Predict using the Random Forest model on X_test data
test_Accuracy = accuracy_score(Y_test, y_pred)  # Calculate the accuracy of Random Forest model using Y_test and y_pred
print("Random Forest Testing Accuracy:", test_Accuracy)

y_pred = random_model.predict(X_train) # Predict using the Random Forest model on X_train data
train_Accuracy = accuracy_score(Y_train, y_pred)  # Calculate the accuracy of Random Forest model using Y_train and y_pred
print("Random Forest Training Accuracy:", train_Accuracy)

initial_All_Model_Acc['random_Forest']= test_Accuracy*100   # Store the testing accuracy of Random Forest model in dictionary
inital_All_Model_Training_Accuracy['random_Forest']= train_Accuracy*100  # Store the training accuracy of Random Forest model in dictionary
# Out:
# Random Forest Testing Accuracy: 0.9243481454278369
# Random Forest Training Accuracy: 1.0

# %% [markdown]
# Support Vector Machines (SVM)

# %%
from sklearn import svm

# %%
# Create SVM classifier
svm = svm.SVC(kernel='linear')

# %%
# Fit SVM classifier on training data
svm.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
# Make predictions on the testing data and Calculate the accuracy of the Support Vector Machines (SVM) model

y_pred = svm.predict(X_test)   # Predict using the SVM model on X_test data
test_Accuracy = accuracy_score(Y_test, y_pred)  # Calculate the accuracy of SVM model using Y_test and y_pred
print("SVM Testing Accuracy:", test_Accuracy)

y_pred = svm.predict(X_train)  # Predict using the SVM model on X_train data
train_Accuracy = accuracy_score(Y_train, y_pred)  # Calculate the accuracy of SVM model using Y_train and y_pred
print("SVM Training Accuracy:", train_Accuracy)

initial_All_Model_Acc['Svm']= test_Accuracy*100   # Store the testing accuracy of SVM model in dictionary
inital_All_Model_Training_Accuracy['Svm']= train_Accuracy*100  # Store the training accuracy of SVM model in dictionary
# Out:
# SVM Testing Accuracy: 0.9217774513404333
# SVM Training Accuracy: 0.928269654665687

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
# Create an instance of Gaussian Naive Bayes classifier
gnb = GaussianNB()

# %%
# Train the model using the training data
gnb.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
# Make predictions on the testing data and Calculate the accuracy of the Naive Bayes model

y_pred = gnb.predict(X_test)  # Predict using the Naive Bayes  model on X_test data
test_Accuracy = accuracy_score(Y_test, y_pred)   # Calculate the accuracy of Naive Bayes model using Y_test and y_pred
print("Naive Bayes Testing Accuracy:", test_Accuracy)

y_pred = gnb.predict(X_train)   # Predict using the  Naive Bayes model on X_train data
train_Accuracy = accuracy_score(Y_train, y_pred)  # Calculate the accuracy of  Naive Bayes model using Y_train and y_pred
print("Naive Bayes Training Accuracy:", train_Accuracy)

initial_All_Model_Acc['naive_Bayes']= test_Accuracy*100    # Store the testing accuracy of  Naive Bayes model in dictionary
inital_All_Model_Training_Accuracy['naive_Bayes']= train_Accuracy*100   # Store the training accuracy of  Naive Bayes model in dictionary
# Out:
# Naive Bayes Testing Accuracy: 0.8964377524788836
# Naive Bayes Training Accuracy: 0.897685525349008

# %% [markdown]
# Gradient Boosting Machines (GBM)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Initialize the GBM model
gbm = GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=100, max_depth=3)

# %%
# Fit the model to the training data
gbm.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# GradientBoostingClassifier(loss='deviance')

# %%
# Make predictions on the testing data and Calculate the accuracy of the Gradient Boosting Machines model

y_pred = gbm.predict(X_test) # Predict using the  Gradient Boosting  model on X_test data
test_Accuracy = accuracy_score(Y_test, y_pred)  # Calculate the accuracy of Gradient Boosting  model using Y_test and y_pred
print("Gradient Boosting Testing Accuracy:", test_Accuracy)

y_pred = gbm.predict(X_train)   # Predict using the Gradient Boosting  model on X_train data
train_Accuracy = accuracy_score(Y_train, y_pred)  # Calculate the accuracy of Gradient Boosting  model using Y_train and y_pred
print("Gradient Boosting Training Accuracy:", train_Accuracy)

initial_All_Model_Acc['gradient_Boosting']= test_Accuracy*100    # Store the testing accuracy of Gradient Boosting  model in dictionary
inital_All_Model_Training_Accuracy['gradient_Boosting']= train_Accuracy*100  # Store the training accuracy of Gradient Boosting  model in dictionary
# Out:
# Gradient Boosting Testing Accuracy: 0.9261843554902681
# Gradient Boosting Training Accuracy: 0.9607825128581925

# %% [markdown]
# AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
# Initialize the AdaBoost classifier
clf = AdaBoostClassifier(n_estimators=500, random_state=42)

# %%
# Fit the classifier to the training data
clf.fit(X_train, Y_train)
# Out:
# AdaBoostClassifier(n_estimators=500, random_state=42)

# %%
# Make predictions on the testing data and Calculate the accuracy of the AdaBoost Machines model

y_pred = clf.predict(X_test)   # Predict using the  AdaBoost  model on X_test data
test_Accuracy = accuracy_score(Y_test, y_pred)  # Calculate the accuracy of AdaBoost  model using Y_test and y_pred
print("AdaBoost Testing Accuracy:", test_Accuracy)

y_pred = clf.predict(X_train)   # Predict using the AdaBoost  model on X_train data
train_Accuracy = accuracy_score(Y_train, y_pred)  # Calculate the accuracy of AdaBoost  model using Y_train and y_pred
print("AdaBoost Training Accuracy:", train_Accuracy)

initial_All_Model_Acc['AdaBoost']= test_Accuracy*100  # Store the testing accuracy of AdaBoost  model in dictionary
inital_All_Model_Training_Accuracy['AdaBoost']= train_Accuracy*100  # Store the training accuracy of AdaBoost  model in dictionary
# Out:
# AdaBoost Testing Accuracy: 0.6371648916636063
# AdaBoost Training Accuracy: 0.647685525349008

# %%
# print dictionary containing the testing training model accuracy scores of different algorithms
print(initial_All_Model_Acc)
# Out:
# {'Ann': 92.83878075651855, 'Logistic': 92.25119353654058, 'KNN': 92.2879177377892, 'decision_Tree': 89.7172236503856, 'random_Forest': 92.4348145427837, 'Svm': 92.17774513404333, 'naive_Bayes': 89.64377524788836, 'gradient_Boosting': 92.61843554902681, 'AdaBoost': 63.71648916636063}

# %%
# print dictionary containing the initial training model accuracy scores of different algorithms
inital_All_Model_Training_Accuracy
# Out:
# {'Ann': 94.31484202792065,
#  'Logistic': 92.51469507714916,
#  'KNN': 95.0955180014695,
#  'decision_Tree': 100.0,
#  'random_Forest': 100.0,
#  'Svm': 92.8269654665687,
#  'naive_Bayes': 89.7685525349008,
#  'gradient_Boosting': 96.07825128581925,
#  'AdaBoost': 64.7685525349008}

# %%
fig = plt.figure(figsize=(8, 6)) # Create a new figure with a size of 8 inches (width) by 6 inches (height)
plt.bar(range(len(initial_All_Model_Acc)), list(initial_All_Model_Acc.values()), align='center') # Create a bar chart using the values of the dictionary initial_All_Model_Acc.
plt.xticks(range(len(initial_All_Model_Acc)), list(initial_All_Model_Acc.keys()), rotation=45, ha='right', fontsize=8)
plt.ylim(60, 100)
plt.ylabel('Accuracy (%)') # Set the y-axis label to "Accuracy (%)"
plt.title('Classification Algorithm Performance') # Set the title of the chart to "Classification Algorithm Performance"
plt.show()

# %%
# Sort the data in descending order
sorted_data = sorted(initial_All_Model_Acc.items(), key=lambda x: x[1], reverse=True)   # initial_All_Model_Acc is a dictionary of model names (keys) and their corresponding accuracy scores (values)

fig = plt.figure(figsize=(8, 6))
plt.bar(range(len(sorted_data)), [val for key, val in sorted_data], align='center', color=['#FF5733', '#FFC300', '#DAF7A6', '#C70039', '#900C3F', '#F9A602', '#EFEFEF', '#FF5733', '#FFC300']) # The colors of the bars are specified using a list of hex codes
plt.xticks(range(len(sorted_data)), [key for key, val in sorted_data], rotation=45, ha='right', fontsize=8)
plt.ylim(60, 100)  # Set the y-axis limits to be between 60 and 100
plt.ylabel('Accuracy (%)') # Set the y-axis label
plt.title('Testing Data Performance')   # Set the title of the plot

plt.show() # Show the plot

# %%
# Get the models names
models = list(initial_All_Model_Acc.keys())

# %%
# Get the accuracy values for initial and training data
test_acc = list(initial_All_Model_Acc.values())
train_acc = list(inital_All_Model_Training_Accuracy.values())

# %%
# Set the figure size
fig = plt.figure(figsize=(8, 6))

# Set the bar width
bar_width = 0.35

# Set the positions of the bars on the x-axis
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]

# Create the bar plots
plt.bar(r1, test_acc, color='#7f6d5f', width=bar_width, edgecolor='white', label='Initial Accuracy')
plt.bar(r2, train_acc, color='#557f2d', width=bar_width, edgecolor='white', label='Training Accuracy')

# Add xticks on the middle of the group bars
plt.xlabel('Models', fontweight='bold')
plt.xticks([r + bar_width/2 for r in range(len(models))], models, rotation=45, ha='right', fontsize=8)

# Add y-label and title
plt.ylabel('Accuracy', fontweight='bold')
plt.title('Comparison of Initial and Training Accuracy', fontweight='bold')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
X
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653248  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
# Predict and Decode the numerical values back to categorical labels
decoded_predicted_labels = le.inverse_transform(model.predict(np.array(X_test)).argmax(axis=-1))
print(decoded_predicted_labels)


#make a instance id from testing datasets
instance_ids = x_test.index
# Out:
# 86/86 [==============================] - 0s 1ms/step
# ['DERMASON' 'SIRA' 'CALI' ... 'SEKER' 'DERMASON' 'DERMASON']

# %%
# create a pandas dataframe with the instance IDs and predicted labels'

df_csv = pd.DataFrame({'Instance ID': instance_ids, 'Predicted Label': decoded_predicted_labels})

# save the dataframe to a .csv file
df_csv.to_csv('predictions.csv', index=False)

# %% [markdown]
# hyperparameter

# %%
# create a sequential model object
model = Sequential()   

# add a dense layer with 100 units, ReLU activation function, and input dimension of 16 to the model
model.add(Dense(100,activation='relu',input_dim=16))
model.add(Dense(75,activation='relu'))
# create a sequential model object
model.add(Dense(50,activation='relu'))

# create a sequential model object
model.add(Dense(7,activation='softmax'))

#Complie the model
model.compile(loss='sparse_categorical_crossentropy',  # Use sparse categorical cross-entropy as the loss function
              optimizer=Adam(learning_rate=0.001),  # Use Adam optimizer with learning rate of 0.001
              metrics=['accuracy'])  # Track accuracy as the evaluation metric

# %%
# Train the ANN model on the training data for 50 epochs, with a 32 batch size
# Print the training log information for each epoch (verbose=2)
history = model.fit(X_train, Y_train, epochs=50, batch_size=32, verbose=2,validation_data=(X_test,Y_test))



# Use the trained model to make predictions on the testing dataset and calculate the accuracy of testing dataset
y_pred = model.predict(X_test)  # Get predicted class probabilities of the testing dataset
Y_pred = y_pred.argmax(axis=-1) # Convert above probabilities to class labels
test_Accuracy = accuracy_score(Y_test,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Testing ANN Accuracy: ",test_Accuracy)  # Print the testing accuracy

# Use the trained model to make predictions on the training dataset and calculate the accuracy of training dataset
y_pred = model.predict(X_train)   # Get predicted class probabilities of the training dataset
Y_pred = y_pred.argmax(axis=-1)   # Convert above probabilities to class labels
train_Accuracy = accuracy_score(Y_train,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Training ANN Accuracy: ",train_Accuracy)  # Print the testing accuracy
# Out:
# Epoch 1/50
# 341/341 - 4s - loss: 0.4184 - accuracy: 0.8593 - val_loss: 0.2344 - val_accuracy: 0.9155 - 4s/epoch - 11ms/step
# Epoch 2/50
# 341/341 - 1s - loss: 0.2185 - accuracy: 0.9205 - val_loss: 0.2149 - val_accuracy: 0.9229 - 1s/epoch - 3ms/step
# Epoch 3/50
# 341/341 - 1s - loss: 0.2068 - accuracy: 0.9258 - val_loss: 0.2039 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# Epoch 4/50
# 341/341 - 1s - loss: 0.1994 - accuracy: 0.9280 - val_loss: 0.1946 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 5/50
# 341/341 - 1s - loss: 0.1950 - accuracy: 0.9281 - val_loss: 0.2034 - val_accuracy: 0.9229 - 1s/epoch - 3ms/step
# Epoch 6/50
# 341/341 - 1s - loss: 0.1930 - accuracy: 0.9303 - val_loss: 0.1953 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 7/50
# 341/341 - 1s - loss: 0.1889 - accuracy: 0.9304 - val_loss: 0.1935 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 8/50
# 341/341 - 1s - loss: 0.1879 - accuracy: 0.9311 - val_loss: 0.1920 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 9/50
# 341/341 - 1s - loss: 0.1831 - accuracy: 0.9318 - val_loss: 0.2067 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 10/50
# 341/341 - 1s - loss: 0.1815 - accuracy: 0.9328 - val_loss: 0.1917 - val_accuracy: 0.9273 - 1s/epoch - 4ms/step
# Epoch 11/50
# 341/341 - 2s - loss: 0.1803 - accuracy: 0.9319 - val_loss: 0.1910 - val_accuracy: 0.9288 - 2s/epoch - 4ms/step
# Epoch 12/50
# 341/341 - 1s - loss: 0.1802 - accuracy: 0.9329 - val_loss: 0.2053 - val_accuracy: 0.9254 - 999ms/epoch - 3ms/step
# Epoch 13/50
# 341/341 - 1s - loss: 0.1784 - accuracy: 0.9325 - val_loss: 0.1876 - val_accuracy: 0.9295 - 998ms/epoch - 3ms/step
# Epoch 14/50
# 341/341 - 1s - loss: 0.1786 - accuracy: 0.9318 - val_loss: 0.1995 - val_accuracy: 0.9277 - 987ms/epoch - 3ms/step
# Epoch 15/50
# 341/341 - 1s - loss: 0.1762 - accuracy: 0.9347 - val_loss: 0.1942 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 16/50
# 341/341 - 1s - loss: 0.1730 - accuracy: 0.9345 - val_loss: 0.2231 - val_accuracy: 0.9177 - 1s/epoch - 3ms/step
# Epoch 17/50
# 341/341 - 1s - loss: 0.1707 - accuracy: 0.9364 - val_loss: 0.1846 - val_accuracy: 0.9302 - 981ms/epoch - 3ms/step
# Epoch 18/50
# 341/341 - 1s - loss: 0.1732 - accuracy: 0.9344 - val_loss: 0.1888 - val_accuracy: 0.9339 - 986ms/epoch - 3ms/step
# Epoch 19/50
# 341/341 - 1s - loss: 0.1696 - accuracy: 0.9366 - val_loss: 0.1876 - val_accuracy: 0.9291 - 980ms/epoch - 3ms/step
# Epoch 20/50
# 341/341 - 1s - loss: 0.1687 - accuracy: 0.9367 - val_loss: 0.1941 - val_accuracy: 0.9317 - 1s/epoch - 3ms/step
# Epoch 21/50
# 341/341 - 1s - loss: 0.1683 - accuracy: 0.9364 - val_loss: 0.1962 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 22/50
# 341/341 - 1s - loss: 0.1665 - accuracy: 0.9383 - val_loss: 0.1930 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 23/50
# 341/341 - 1s - loss: 0.1647 - accuracy: 0.9382 - val_loss: 0.2009 - val_accuracy: 0.9284 - 991ms/epoch - 3ms/step
# Epoch 24/50
# 341/341 - 1s - loss: 0.1653 - accuracy: 0.9379 - val_loss: 0.1877 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 25/50
# 341/341 - 1s - loss: 0.1627 - accuracy: 0.9370 - val_loss: 0.1920 - val_accuracy: 0.9310 - 986ms/epoch - 3ms/step
# Epoch 26/50
# 341/341 - 1s - loss: 0.1630 - accuracy: 0.9378 - val_loss: 0.1994 - val_accuracy: 0.9295 - 978ms/epoch - 3ms/step
# Epoch 27/50
# 341/341 - 1s - loss: 0.1608 - accuracy: 0.9394 - val_loss: 0.2080 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 28/50
# 341/341 - 1s - loss: 0.1596 - accuracy: 0.9384 - val_loss: 0.1957 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 29/50
# 341/341 - 1s - loss: 0.1608 - accuracy: 0.9376 - val_loss: 0.1916 - val_accuracy: 0.9277 - 979ms/epoch - 3ms/step
# Epoch 30/50
# 341/341 - 1s - loss: 0.1581 - accuracy: 0.9393 - val_loss: 0.1948 - val_accuracy: 0.9280 - 998ms/epoch - 3ms/step
# Epoch 31/50
# 341/341 - 1s - loss: 0.1586 - accuracy: 0.9385 - val_loss: 0.1987 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 32/50
# 341/341 - 1s - loss: 0.1583 - accuracy: 0.9393 - val_loss: 0.1963 - val_accuracy: 0.9236 - 1s/epoch - 4ms/step
# Epoch 33/50
# 341/341 - 2s - loss: 0.1568 - accuracy: 0.9383 - val_loss: 0.1919 - val_accuracy: 0.9295 - 2s/epoch - 4ms/step
# Epoch 34/50
# 341/341 - 1s - loss: 0.1543 - accuracy: 0.9409 - val_loss: 0.1979 - val_accuracy: 0.9317 - 997ms/epoch - 3ms/step
# Epoch 35/50
# 341/341 - 1s - loss: 0.1543 - accuracy: 0.9411 - val_loss: 0.1946 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 36/50
# 341/341 - 1s - loss: 0.1545 - accuracy: 0.9392 - val_loss: 0.1926 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 37/50
# 341/341 - 1s - loss: 0.1529 - accuracy: 0.9418 - val_loss: 0.1999 - val_accuracy: 0.9324 - 1s/epoch - 3ms/step
# Epoch 38/50
# 341/341 - 1s - loss: 0.1482 - accuracy: 0.9435 - val_loss: 0.1874 - val_accuracy: 0.9328 - 1s/epoch - 3ms/step
# Epoch 39/50
# 341/341 - 1s - loss: 0.1510 - accuracy: 0.9430 - val_loss: 0.1954 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 40/50
# 341/341 - 1s - loss: 0.1494 - accuracy: 0.9418 - val_loss: 0.1884 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 41/50
# 341/341 - 1s - loss: 0.1480 - accuracy: 0.9427 - val_loss: 0.2036 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 42/50
# 341/341 - 1s - loss: 0.1475 - accuracy: 0.9423 - val_loss: 0.1960 - val_accuracy: 0.9332 - 1s/epoch - 3ms/step
# Epoch 43/50
# 341/341 - 1s - loss: 0.1480 - accuracy: 0.9439 - val_loss: 0.1993 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 44/50
# 341/341 - 1s - loss: 0.1443 - accuracy: 0.9450 - val_loss: 0.1995 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 45/50
# 341/341 - 1s - loss: 0.1442 - accuracy: 0.9443 - val_loss: 0.2012 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 46/50
# 341/341 - 1s - loss: 0.1421 - accuracy: 0.9444 - val_loss: 0.1944 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 47/50
# 341/341 - 1s - loss: 0.1420 - accuracy: 0.9445 - val_loss: 0.2038 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 48/50
# 341/341 - 1s - loss: 0.1405 - accuracy: 0.9450 - val_loss: 0.2223 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 49/50
# 341/341 - 1s - loss: 0.1428 - accuracy: 0.9438 - val_loss: 0.1940 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 50/50
# 341/341 - 1s - loss: 0.1399 - accuracy: 0.9462 - val_loss: 0.2100 - val_accuracy: 0.9280 - 986ms/epoch - 3ms/step
# 86/86 [==============================] - 0s 1ms/step
# Testing ANN Accuracy:  0.9280205655526992
# 341/341 [==============================] - 1s 1ms/step
# Training ANN Accuracy:  0.9461792799412196

# %%
# create a sequential model object
model = Sequential()   

# add a dense layer with 100 units, ReLU activation function, and input dimension of 16 to the model
model.add(Dense(100,activation='relu',input_dim=16))
model.add(Dense(75,activation='relu'))
# create a sequential model object
model.add(Dense(50,activation='relu'))

# create a sequential model object
model.add(Dense(7,activation='softmax'))

#Complie the model
model.compile(loss='sparse_categorical_crossentropy',  # Use sparse categorical cross-entropy as the loss function
              optimizer=Adam(learning_rate=0.001),  # Use Adam optimizer with learning rate of 0.001
              metrics=['accuracy'])  # Track accuracy as the evaluation metric

# %%
# Train the ANN model on the training data for 100 epochs, with a 32 batch size
# Print the training log information for each epoch (verbose=2)
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, verbose=2,validation_data=(X_test,Y_test))



# Use the trained model to make predictions on the testing dataset and calculate the accuracy of testing dataset
y_pred = model.predict(X_test)  # Get predicted class probabilities of the testing dataset
Y_pred = y_pred.argmax(axis=-1) # Convert above probabilities to class labels
test_Accuracy = accuracy_score(Y_test,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Testing ANN Accuracy: ",test_Accuracy)  # Print the testing accuracy

# Use the trained model to make predictions on the training dataset and calculate the accuracy of training dataset
y_pred = model.predict(X_train)   # Get predicted class probabilities of the training dataset
Y_pred = y_pred.argmax(axis=-1)   # Convert above probabilities to class labels
train_Accuracy = accuracy_score(Y_train,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Training ANN Accuracy: ",train_Accuracy)  # Print the testing accuracy
# Out:
# Epoch 1/100
# 341/341 - 3s - loss: 0.4035 - accuracy: 0.8689 - val_loss: 0.2235 - val_accuracy: 0.9163 - 3s/epoch - 10ms/step
# Epoch 2/100
# 341/341 - 1s - loss: 0.2138 - accuracy: 0.9233 - val_loss: 0.2432 - val_accuracy: 0.9089 - 985ms/epoch - 3ms/step
# Epoch 3/100
# 341/341 - 1s - loss: 0.2068 - accuracy: 0.9248 - val_loss: 0.2061 - val_accuracy: 0.9203 - 984ms/epoch - 3ms/step
# Epoch 4/100
# 341/341 - 1s - loss: 0.2005 - accuracy: 0.9242 - val_loss: 0.1989 - val_accuracy: 0.9258 - 999ms/epoch - 3ms/step
# Epoch 5/100
# 341/341 - 1s - loss: 0.1955 - accuracy: 0.9267 - val_loss: 0.2008 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 6/100
# 341/341 - 1s - loss: 0.1897 - accuracy: 0.9307 - val_loss: 0.1914 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 7/100
# 341/341 - 1s - loss: 0.1897 - accuracy: 0.9298 - val_loss: 0.1918 - val_accuracy: 0.9251 - 967ms/epoch - 3ms/step
# Epoch 8/100
# 341/341 - 1s - loss: 0.1875 - accuracy: 0.9332 - val_loss: 0.1987 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 9/100
# 341/341 - 1s - loss: 0.1893 - accuracy: 0.9305 - val_loss: 0.1878 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 10/100
# 341/341 - 1s - loss: 0.1833 - accuracy: 0.9327 - val_loss: 0.1895 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 11/100
# 341/341 - 2s - loss: 0.1820 - accuracy: 0.9329 - val_loss: 0.1929 - val_accuracy: 0.9277 - 2s/epoch - 5ms/step
# Epoch 12/100
# 341/341 - 1s - loss: 0.1814 - accuracy: 0.9318 - val_loss: 0.1961 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 13/100
# 341/341 - 1s - loss: 0.1765 - accuracy: 0.9340 - val_loss: 0.2021 - val_accuracy: 0.9240 - 993ms/epoch - 3ms/step
# Epoch 14/100
# 341/341 - 1s - loss: 0.1817 - accuracy: 0.9330 - val_loss: 0.1882 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 15/100
# 341/341 - 1s - loss: 0.1762 - accuracy: 0.9335 - val_loss: 0.1958 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 16/100
# 341/341 - 1s - loss: 0.1748 - accuracy: 0.9339 - val_loss: 0.1873 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 17/100
# 341/341 - 1s - loss: 0.1758 - accuracy: 0.9342 - val_loss: 0.1853 - val_accuracy: 0.9291 - 1s/epoch - 4ms/step
# Epoch 18/100
# 341/341 - 1s - loss: 0.1713 - accuracy: 0.9349 - val_loss: 0.1871 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 19/100
# 341/341 - 1s - loss: 0.1700 - accuracy: 0.9346 - val_loss: 0.1977 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 20/100
# 341/341 - 1s - loss: 0.1708 - accuracy: 0.9337 - val_loss: 0.2040 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 21/100
# 341/341 - 1s - loss: 0.1702 - accuracy: 0.9344 - val_loss: 0.1872 - val_accuracy: 0.9302 - 1s/epoch - 4ms/step
# Epoch 22/100
# 341/341 - 1s - loss: 0.1683 - accuracy: 0.9353 - val_loss: 0.1959 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 23/100
# 341/341 - 1s - loss: 0.1678 - accuracy: 0.9357 - val_loss: 0.1952 - val_accuracy: 0.9258 - 990ms/epoch - 3ms/step
# Epoch 24/100
# 341/341 - 1s - loss: 0.1673 - accuracy: 0.9366 - val_loss: 0.1983 - val_accuracy: 0.9291 - 986ms/epoch - 3ms/step
# Epoch 25/100
# 341/341 - 1s - loss: 0.1644 - accuracy: 0.9375 - val_loss: 0.1914 - val_accuracy: 0.9321 - 993ms/epoch - 3ms/step
# Epoch 26/100
# 341/341 - 1s - loss: 0.1618 - accuracy: 0.9386 - val_loss: 0.1891 - val_accuracy: 0.9321 - 990ms/epoch - 3ms/step
# Epoch 27/100
# 341/341 - 1s - loss: 0.1623 - accuracy: 0.9373 - val_loss: 0.2022 - val_accuracy: 0.9306 - 998ms/epoch - 3ms/step
# Epoch 28/100
# 341/341 - 1s - loss: 0.1675 - accuracy: 0.9341 - val_loss: 0.1859 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 29/100
# 341/341 - 1s - loss: 0.1621 - accuracy: 0.9368 - val_loss: 0.1878 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 30/100
# 341/341 - 1s - loss: 0.1595 - accuracy: 0.9380 - val_loss: 0.2204 - val_accuracy: 0.9207 - 1s/epoch - 3ms/step
# Epoch 31/100
# 341/341 - 1s - loss: 0.1612 - accuracy: 0.9390 - val_loss: 0.1939 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 32/100
# 341/341 - 1s - loss: 0.1597 - accuracy: 0.9393 - val_loss: 0.1960 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 33/100
# 341/341 - 1s - loss: 0.1567 - accuracy: 0.9392 - val_loss: 0.1957 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 34/100
# 341/341 - 1s - loss: 0.1573 - accuracy: 0.9380 - val_loss: 0.1891 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 35/100
# 341/341 - 1s - loss: 0.1564 - accuracy: 0.9386 - val_loss: 0.1988 - val_accuracy: 0.9284 - 999ms/epoch - 3ms/step
# Epoch 36/100
# 341/341 - 1s - loss: 0.1549 - accuracy: 0.9412 - val_loss: 0.2014 - val_accuracy: 0.9258 - 970ms/epoch - 3ms/step
# Epoch 37/100
# 341/341 - 1s - loss: 0.1529 - accuracy: 0.9419 - val_loss: 0.1970 - val_accuracy: 0.9317 - 990ms/epoch - 3ms/step
# Epoch 38/100
# 341/341 - 1s - loss: 0.1536 - accuracy: 0.9407 - val_loss: 0.1995 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 39/100
# 341/341 - 1s - loss: 0.1533 - accuracy: 0.9404 - val_loss: 0.1880 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 40/100
# 341/341 - 1s - loss: 0.1507 - accuracy: 0.9410 - val_loss: 0.1986 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 41/100
# 341/341 - 1s - loss: 0.1502 - accuracy: 0.9431 - val_loss: 0.1860 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 42/100
# 341/341 - 1s - loss: 0.1523 - accuracy: 0.9414 - val_loss: 0.2176 - val_accuracy: 0.9221 - 1s/epoch - 3ms/step
# Epoch 43/100
# 341/341 - 1s - loss: 0.1500 - accuracy: 0.9397 - val_loss: 0.1945 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 44/100
# 341/341 - 1s - loss: 0.1478 - accuracy: 0.9416 - val_loss: 0.2178 - val_accuracy: 0.9232 - 1s/epoch - 4ms/step
# Epoch 45/100
# 341/341 - 1s - loss: 0.1462 - accuracy: 0.9444 - val_loss: 0.1956 - val_accuracy: 0.9313 - 1s/epoch - 3ms/step
# Epoch 46/100
# 341/341 - 1s - loss: 0.1449 - accuracy: 0.9429 - val_loss: 0.2042 - val_accuracy: 0.9295 - 966ms/epoch - 3ms/step
# Epoch 47/100
# 341/341 - 1s - loss: 0.1448 - accuracy: 0.9435 - val_loss: 0.1986 - val_accuracy: 0.9295 - 995ms/epoch - 3ms/step
# Epoch 48/100
# 341/341 - 1s - loss: 0.1489 - accuracy: 0.9437 - val_loss: 0.2080 - val_accuracy: 0.9266 - 990ms/epoch - 3ms/step
# Epoch 49/100
# 341/341 - 1s - loss: 0.1442 - accuracy: 0.9452 - val_loss: 0.1988 - val_accuracy: 0.9313 - 1s/epoch - 3ms/step
# Epoch 50/100
# 341/341 - 1s - loss: 0.1439 - accuracy: 0.9445 - val_loss: 0.2050 - val_accuracy: 0.9277 - 991ms/epoch - 3ms/step
# Epoch 51/100
# 341/341 - 1s - loss: 0.1419 - accuracy: 0.9449 - val_loss: 0.1997 - val_accuracy: 0.9280 - 997ms/epoch - 3ms/step
# Epoch 52/100
# 341/341 - 1s - loss: 0.1397 - accuracy: 0.9456 - val_loss: 0.2086 - val_accuracy: 0.9258 - 999ms/epoch - 3ms/step
# Epoch 53/100
# 341/341 - 1s - loss: 0.1401 - accuracy: 0.9441 - val_loss: 0.2077 - val_accuracy: 0.9277 - 984ms/epoch - 3ms/step
# Epoch 54/100
# 341/341 - 1s - loss: 0.1370 - accuracy: 0.9454 - val_loss: 0.2060 - val_accuracy: 0.9288 - 1000ms/epoch - 3ms/step
# Epoch 55/100
# 341/341 - 1s - loss: 0.1382 - accuracy: 0.9450 - val_loss: 0.2096 - val_accuracy: 0.9310 - 1s/epoch - 4ms/step
# Epoch 56/100
# 341/341 - 2s - loss: 0.1365 - accuracy: 0.9476 - val_loss: 0.1995 - val_accuracy: 0.9284 - 2s/epoch - 5ms/step
# Epoch 57/100
# 341/341 - 1s - loss: 0.1378 - accuracy: 0.9464 - val_loss: 0.2127 - val_accuracy: 0.9232 - 1s/epoch - 3ms/step
# Epoch 58/100
# 341/341 - 1s - loss: 0.1340 - accuracy: 0.9473 - val_loss: 0.2098 - val_accuracy: 0.9306 - 986ms/epoch - 3ms/step
# Epoch 59/100
# 341/341 - 1s - loss: 0.1338 - accuracy: 0.9454 - val_loss: 0.2145 - val_accuracy: 0.9273 - 999ms/epoch - 3ms/step
# Epoch 60/100
# 341/341 - 1s - loss: 0.1322 - accuracy: 0.9461 - val_loss: 0.2084 - val_accuracy: 0.9288 - 990ms/epoch - 3ms/step
# Epoch 61/100
# 341/341 - 1s - loss: 0.1318 - accuracy: 0.9476 - val_loss: 0.2168 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 62/100
# 341/341 - 1s - loss: 0.1362 - accuracy: 0.9449 - val_loss: 0.2059 - val_accuracy: 0.9299 - 995ms/epoch - 3ms/step
# Epoch 63/100
# 341/341 - 1s - loss: 0.1343 - accuracy: 0.9474 - val_loss: 0.2088 - val_accuracy: 0.9243 - 984ms/epoch - 3ms/step
# Epoch 64/100
# 341/341 - 1s - loss: 0.1294 - accuracy: 0.9478 - val_loss: 0.2279 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 65/100
# 341/341 - 1s - loss: 0.1294 - accuracy: 0.9480 - val_loss: 0.2117 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 66/100
# 341/341 - 1s - loss: 0.1261 - accuracy: 0.9499 - val_loss: 0.2157 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 67/100
# 341/341 - 2s - loss: 0.1282 - accuracy: 0.9481 - val_loss: 0.2132 - val_accuracy: 0.9280 - 2s/epoch - 4ms/step
# Epoch 68/100
# 341/341 - 1s - loss: 0.1304 - accuracy: 0.9488 - val_loss: 0.2079 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 69/100
# 341/341 - 1s - loss: 0.1243 - accuracy: 0.9484 - val_loss: 0.2252 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 70/100
# 341/341 - 1s - loss: 0.1271 - accuracy: 0.9492 - val_loss: 0.2248 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 71/100
# 341/341 - 1s - loss: 0.1243 - accuracy: 0.9526 - val_loss: 0.2332 - val_accuracy: 0.9229 - 1s/epoch - 3ms/step
# Epoch 72/100
# 341/341 - 1s - loss: 0.1236 - accuracy: 0.9499 - val_loss: 0.2253 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 73/100
# 341/341 - 1s - loss: 0.1229 - accuracy: 0.9510 - val_loss: 0.2256 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 74/100
# 341/341 - 1s - loss: 0.1206 - accuracy: 0.9506 - val_loss: 0.2408 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 75/100
# 341/341 - 1s - loss: 0.1234 - accuracy: 0.9492 - val_loss: 0.2384 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 76/100
# 341/341 - 1s - loss: 0.1207 - accuracy: 0.9521 - val_loss: 0.2365 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 77/100
# 341/341 - 2s - loss: 0.1198 - accuracy: 0.9512 - val_loss: 0.2325 - val_accuracy: 0.9232 - 2s/epoch - 4ms/step
# Epoch 78/100
# 341/341 - 1s - loss: 0.1218 - accuracy: 0.9509 - val_loss: 0.2400 - val_accuracy: 0.9225 - 1s/epoch - 3ms/step
# Epoch 79/100
# 341/341 - 1s - loss: 0.1205 - accuracy: 0.9508 - val_loss: 0.2434 - val_accuracy: 0.9214 - 996ms/epoch - 3ms/step
# Epoch 80/100
# 341/341 - 1s - loss: 0.1156 - accuracy: 0.9527 - val_loss: 0.2320 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 81/100
# 341/341 - 1s - loss: 0.1206 - accuracy: 0.9519 - val_loss: 0.2349 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 82/100
# 341/341 - 1s - loss: 0.1147 - accuracy: 0.9546 - val_loss: 0.2335 - val_accuracy: 0.9277 - 1000ms/epoch - 3ms/step
# Epoch 83/100
# 341/341 - 1s - loss: 0.1135 - accuracy: 0.9539 - val_loss: 0.2325 - val_accuracy: 0.9280 - 987ms/epoch - 3ms/step
# Epoch 84/100
# 341/341 - 1s - loss: 0.1117 - accuracy: 0.9538 - val_loss: 0.2370 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 85/100
# 341/341 - 1s - loss: 0.1106 - accuracy: 0.9551 - val_loss: 0.2403 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 86/100
# 341/341 - 1s - loss: 0.1134 - accuracy: 0.9530 - val_loss: 0.2493 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 87/100
# 341/341 - 1s - loss: 0.1117 - accuracy: 0.9549 - val_loss: 0.2619 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 88/100
# 341/341 - 1s - loss: 0.1125 - accuracy: 0.9562 - val_loss: 0.2493 - val_accuracy: 0.9269 - 1s/epoch - 4ms/step
# Epoch 89/100
# 341/341 - 1s - loss: 0.1120 - accuracy: 0.9543 - val_loss: 0.2477 - val_accuracy: 0.9262 - 1s/epoch - 4ms/step
# Epoch 90/100
# 341/341 - 1s - loss: 0.1121 - accuracy: 0.9549 - val_loss: 0.2455 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 91/100
# 341/341 - 1s - loss: 0.1102 - accuracy: 0.9550 - val_loss: 0.2531 - val_accuracy: 0.9229 - 991ms/epoch - 3ms/step
# Epoch 92/100
# 341/341 - 1s - loss: 0.1117 - accuracy: 0.9541 - val_loss: 0.2479 - val_accuracy: 0.9280 - 988ms/epoch - 3ms/step
# Epoch 93/100
# 341/341 - 1s - loss: 0.1059 - accuracy: 0.9572 - val_loss: 0.2461 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 94/100
# 341/341 - 1s - loss: 0.1020 - accuracy: 0.9594 - val_loss: 0.2601 - val_accuracy: 0.9243 - 1s/epoch - 3ms/step
# Epoch 95/100
# 341/341 - 1s - loss: 0.1035 - accuracy: 0.9585 - val_loss: 0.2541 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 96/100
# 341/341 - 1s - loss: 0.1052 - accuracy: 0.9561 - val_loss: 0.2641 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 97/100
# 341/341 - 1s - loss: 0.1083 - accuracy: 0.9560 - val_loss: 0.2589 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 98/100
# 341/341 - 1s - loss: 0.1013 - accuracy: 0.9578 - val_loss: 0.2725 - val_accuracy: 0.9243 - 987ms/epoch - 3ms/step
# Epoch 99/100
# 341/341 - 1s - loss: 0.1011 - accuracy: 0.9591 - val_loss: 0.2740 - val_accuracy: 0.9203 - 1s/epoch - 4ms/step
# Epoch 100/100
# 341/341 - 1s - loss: 0.1011 - accuracy: 0.9594 - val_loss: 0.2716 - val_accuracy: 0.9225 - 1s/epoch - 4ms/step
# 86/86 [==============================] - 0s 1ms/step
# Testing ANN Accuracy:  0.9225119353654058
# 341/341 [==============================] - 1s 1ms/step
# Training ANN Accuracy:  0.9586700955180014

# %%
# create a sequential model object
model = Sequential()   

# add a dense layer with 100 units, ReLU activation function, and input dimension of 16 to the model
model.add(Dense(100,activation='relu',input_dim=16))
model.add(Dropout(0.4))
model.add(Dense(75,activation='relu'))
# create a sequential model object
model.add(Dropout(0.4))
model.add(Dense(50,activation='relu'))

# create a sequential model object
model.add(Dense(7,activation='softmax'))

#Complie the model
model.compile(loss='sparse_categorical_crossentropy',  # Use sparse categorical cross-entropy as the loss function
              optimizer=Adam(learning_rate=0.001),  # Use Adam optimizer with learning rate of 0.001
              metrics=['accuracy'])  # Track accuracy as the evaluation metric

# %%
# Train the ANN model on the training data for 100 epochs, with a 32 batch size
# Print the training log information for each epoch (verbose=2)
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, verbose=2,validation_data=(X_test,Y_test))

print("********************************************************")

# Use the trained model to make predictions on the testing dataset and calculate the accuracy of testing dataset
y_pred = model.predict(X_test)  # Get predicted class probabilities of the testing dataset
Y_pred = y_pred.argmax(axis=-1) # Convert above probabilities to class labels
test_Accuracy = accuracy_score(Y_test,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Testing ANN Accuracy: ",test_Accuracy)  # Print the testing accuracy

# Use the trained model to make predictions on the training dataset and calculate the accuracy of training dataset
y_pred = model.predict(X_train)   # Get predicted class probabilities of the training dataset
Y_pred = y_pred.argmax(axis=-1)   # Convert above probabilities to class labels
train_Accuracy = accuracy_score(Y_train,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Training ANN Accuracy: ",train_Accuracy)  # Print the testing accuracy
# Out:
# Epoch 1/100
# 341/341 - 4s - loss: 0.6935 - accuracy: 0.7370 - val_loss: 0.2692 - val_accuracy: 0.9060 - 4s/epoch - 11ms/step
# Epoch 2/100
# 341/341 - 1s - loss: 0.3463 - accuracy: 0.8839 - val_loss: 0.2285 - val_accuracy: 0.9196 - 1s/epoch - 3ms/step
# Epoch 3/100
# 341/341 - 1s - loss: 0.3008 - accuracy: 0.8992 - val_loss: 0.2099 - val_accuracy: 0.9210 - 1s/epoch - 3ms/step
# Epoch 4/100
# 341/341 - 1s - loss: 0.2806 - accuracy: 0.9022 - val_loss: 0.2055 - val_accuracy: 0.9229 - 1s/epoch - 3ms/step
# Epoch 5/100
# 341/341 - 1s - loss: 0.2696 - accuracy: 0.9082 - val_loss: 0.2055 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 6/100
# 341/341 - 1s - loss: 0.2584 - accuracy: 0.9120 - val_loss: 0.2022 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 7/100
# 341/341 - 1s - loss: 0.2567 - accuracy: 0.9129 - val_loss: 0.1985 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 8/100
# 341/341 - 1s - loss: 0.2532 - accuracy: 0.9127 - val_loss: 0.1961 - val_accuracy: 0.9243 - 1s/epoch - 4ms/step
# Epoch 9/100
# 341/341 - 1s - loss: 0.2430 - accuracy: 0.9161 - val_loss: 0.1940 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 10/100
# 341/341 - 1s - loss: 0.2471 - accuracy: 0.9161 - val_loss: 0.1954 - val_accuracy: 0.9243 - 1s/epoch - 4ms/step
# Epoch 11/100
# 341/341 - 2s - loss: 0.2395 - accuracy: 0.9180 - val_loss: 0.1959 - val_accuracy: 0.9251 - 2s/epoch - 5ms/step
# Epoch 12/100
# 341/341 - 1s - loss: 0.2388 - accuracy: 0.9165 - val_loss: 0.1937 - val_accuracy: 0.9262 - 1s/epoch - 4ms/step
# Epoch 13/100
# 341/341 - 1s - loss: 0.2325 - accuracy: 0.9184 - val_loss: 0.1964 - val_accuracy: 0.9236 - 1s/epoch - 3ms/step
# Epoch 14/100
# 341/341 - 1s - loss: 0.2365 - accuracy: 0.9170 - val_loss: 0.1986 - val_accuracy: 0.9243 - 1s/epoch - 3ms/step
# Epoch 15/100
# 341/341 - 1s - loss: 0.2293 - accuracy: 0.9201 - val_loss: 0.1928 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 16/100
# 341/341 - 1s - loss: 0.2279 - accuracy: 0.9216 - val_loss: 0.1997 - val_accuracy: 0.9229 - 1s/epoch - 3ms/step
# Epoch 17/100
# 341/341 - 1s - loss: 0.2333 - accuracy: 0.9195 - val_loss: 0.2003 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 18/100
# 341/341 - 1s - loss: 0.2263 - accuracy: 0.9218 - val_loss: 0.1923 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 19/100
# 341/341 - 1s - loss: 0.2271 - accuracy: 0.9213 - val_loss: 0.1899 - val_accuracy: 0.9313 - 1s/epoch - 3ms/step
# Epoch 20/100
# 341/341 - 1s - loss: 0.2252 - accuracy: 0.9206 - val_loss: 0.1885 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 21/100
# 341/341 - 1s - loss: 0.2207 - accuracy: 0.9233 - val_loss: 0.1864 - val_accuracy: 0.9332 - 1s/epoch - 4ms/step
# Epoch 22/100
# 341/341 - 1s - loss: 0.2284 - accuracy: 0.9205 - val_loss: 0.1930 - val_accuracy: 0.9240 - 1s/epoch - 4ms/step
# Epoch 23/100
# 341/341 - 1s - loss: 0.2206 - accuracy: 0.9240 - val_loss: 0.1884 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 24/100
# 341/341 - 1s - loss: 0.2198 - accuracy: 0.9241 - val_loss: 0.1904 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 25/100
# 341/341 - 1s - loss: 0.2187 - accuracy: 0.9199 - val_loss: 0.1979 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 26/100
# 341/341 - 1s - loss: 0.2160 - accuracy: 0.9229 - val_loss: 0.1903 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 27/100
# 341/341 - 1s - loss: 0.2194 - accuracy: 0.9205 - val_loss: 0.1901 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 28/100
# 341/341 - 1s - loss: 0.2190 - accuracy: 0.9219 - val_loss: 0.1933 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 29/100
# 341/341 - 1s - loss: 0.2170 - accuracy: 0.9217 - val_loss: 0.1908 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 30/100
# 341/341 - 1s - loss: 0.2122 - accuracy: 0.9241 - val_loss: 0.1891 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# Epoch 31/100
# 341/341 - 1s - loss: 0.2154 - accuracy: 0.9229 - val_loss: 0.1917 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 32/100
# 341/341 - 2s - loss: 0.2146 - accuracy: 0.9265 - val_loss: 0.1880 - val_accuracy: 0.9280 - 2s/epoch - 4ms/step
# Epoch 33/100
# 341/341 - 1s - loss: 0.2151 - accuracy: 0.9265 - val_loss: 0.1866 - val_accuracy: 0.9313 - 1s/epoch - 4ms/step
# Epoch 34/100
# 341/341 - 1s - loss: 0.2188 - accuracy: 0.9230 - val_loss: 0.1870 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 35/100
# 341/341 - 1s - loss: 0.2126 - accuracy: 0.9261 - val_loss: 0.1950 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 36/100
# 341/341 - 1s - loss: 0.2141 - accuracy: 0.9235 - val_loss: 0.1985 - val_accuracy: 0.9273 - 1s/epoch - 4ms/step
# Epoch 37/100
# 341/341 - 1s - loss: 0.2076 - accuracy: 0.9229 - val_loss: 0.1900 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 38/100
# 341/341 - 1s - loss: 0.2097 - accuracy: 0.9253 - val_loss: 0.1858 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 39/100
# 341/341 - 1s - loss: 0.2144 - accuracy: 0.9248 - val_loss: 0.1892 - val_accuracy: 0.9269 - 1s/epoch - 4ms/step
# Epoch 40/100
# 341/341 - 1s - loss: 0.2123 - accuracy: 0.9261 - val_loss: 0.1865 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 41/100
# 341/341 - 1s - loss: 0.2065 - accuracy: 0.9276 - val_loss: 0.1921 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 42/100
# 341/341 - 1s - loss: 0.2120 - accuracy: 0.9268 - val_loss: 0.1908 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 43/100
# 341/341 - 1s - loss: 0.2073 - accuracy: 0.9248 - val_loss: 0.1909 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 44/100
# 341/341 - 1s - loss: 0.2103 - accuracy: 0.9243 - val_loss: 0.1934 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 45/100
# 341/341 - 1s - loss: 0.2116 - accuracy: 0.9255 - val_loss: 0.1861 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 46/100
# 341/341 - 1s - loss: 0.2057 - accuracy: 0.9262 - val_loss: 0.1908 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 47/100
# 341/341 - 1s - loss: 0.2046 - accuracy: 0.9263 - val_loss: 0.1885 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 48/100
# 341/341 - 1s - loss: 0.2103 - accuracy: 0.9283 - val_loss: 0.1979 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 49/100
# 341/341 - 1s - loss: 0.2029 - accuracy: 0.9275 - val_loss: 0.1881 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 50/100
# 341/341 - 1s - loss: 0.2039 - accuracy: 0.9260 - val_loss: 0.2003 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 51/100
# 341/341 - 1s - loss: 0.2083 - accuracy: 0.9262 - val_loss: 0.1877 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 52/100
# 341/341 - 1s - loss: 0.2108 - accuracy: 0.9268 - val_loss: 0.1900 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 53/100
# 341/341 - 1s - loss: 0.2070 - accuracy: 0.9276 - val_loss: 0.1980 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 54/100
# 341/341 - 1s - loss: 0.2031 - accuracy: 0.9266 - val_loss: 0.1924 - val_accuracy: 0.9299 - 1s/epoch - 4ms/step
# Epoch 55/100
# 341/341 - 1s - loss: 0.2060 - accuracy: 0.9260 - val_loss: 0.1918 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 56/100
# 341/341 - 1s - loss: 0.2082 - accuracy: 0.9238 - val_loss: 0.1838 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 57/100
# 341/341 - 1s - loss: 0.2018 - accuracy: 0.9274 - val_loss: 0.1862 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 58/100
# 341/341 - 1s - loss: 0.1974 - accuracy: 0.9285 - val_loss: 0.1873 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 59/100
# 341/341 - 1s - loss: 0.2036 - accuracy: 0.9269 - val_loss: 0.1950 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 60/100
# 341/341 - 1s - loss: 0.2034 - accuracy: 0.9275 - val_loss: 0.1852 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 61/100
# 341/341 - 1s - loss: 0.2017 - accuracy: 0.9283 - val_loss: 0.1880 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 62/100
# 341/341 - 1s - loss: 0.2033 - accuracy: 0.9274 - val_loss: 0.1858 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 63/100
# 341/341 - 1s - loss: 0.2029 - accuracy: 0.9266 - val_loss: 0.1936 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 64/100
# 341/341 - 1s - loss: 0.2026 - accuracy: 0.9259 - val_loss: 0.1877 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 65/100
# 341/341 - 1s - loss: 0.2002 - accuracy: 0.9270 - val_loss: 0.1903 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 66/100
# 341/341 - 1s - loss: 0.2045 - accuracy: 0.9284 - val_loss: 0.1877 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 67/100
# 341/341 - 1s - loss: 0.1953 - accuracy: 0.9299 - val_loss: 0.1917 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 68/100
# 341/341 - 1s - loss: 0.2034 - accuracy: 0.9274 - val_loss: 0.1875 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 69/100
# 341/341 - 2s - loss: 0.1981 - accuracy: 0.9295 - val_loss: 0.1886 - val_accuracy: 0.9266 - 2s/epoch - 5ms/step
# Epoch 70/100
# 341/341 - 1s - loss: 0.2034 - accuracy: 0.9277 - val_loss: 0.1887 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 71/100
# 341/341 - 1s - loss: 0.2026 - accuracy: 0.9276 - val_loss: 0.1854 - val_accuracy: 0.9317 - 1s/epoch - 4ms/step
# Epoch 72/100
# 341/341 - 1s - loss: 0.1995 - accuracy: 0.9282 - val_loss: 0.1884 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 73/100
# 341/341 - 1s - loss: 0.1991 - accuracy: 0.9276 - val_loss: 0.1861 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 74/100
# 341/341 - 2s - loss: 0.1948 - accuracy: 0.9295 - val_loss: 0.1865 - val_accuracy: 0.9295 - 2s/epoch - 5ms/step
# Epoch 75/100
# 341/341 - 1s - loss: 0.1997 - accuracy: 0.9289 - val_loss: 0.1914 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 76/100
# 341/341 - 1s - loss: 0.2006 - accuracy: 0.9301 - val_loss: 0.1873 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 77/100
# 341/341 - 1s - loss: 0.1990 - accuracy: 0.9269 - val_loss: 0.1886 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 78/100
# 341/341 - 1s - loss: 0.1917 - accuracy: 0.9299 - val_loss: 0.1907 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 79/100
# 341/341 - 1s - loss: 0.1974 - accuracy: 0.9281 - val_loss: 0.1918 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 80/100
# 341/341 - 1s - loss: 0.1972 - accuracy: 0.9304 - val_loss: 0.1935 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 81/100
# 341/341 - 1s - loss: 0.1958 - accuracy: 0.9301 - val_loss: 0.1853 - val_accuracy: 0.9324 - 1s/epoch - 3ms/step
# Epoch 82/100
# 341/341 - 1s - loss: 0.1972 - accuracy: 0.9290 - val_loss: 0.1890 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 83/100
# 341/341 - 1s - loss: 0.1957 - accuracy: 0.9298 - val_loss: 0.1876 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 84/100
# 341/341 - 1s - loss: 0.1980 - accuracy: 0.9271 - val_loss: 0.1874 - val_accuracy: 0.9291 - 1s/epoch - 4ms/step
# Epoch 85/100
# 341/341 - 2s - loss: 0.1989 - accuracy: 0.9260 - val_loss: 0.1861 - val_accuracy: 0.9291 - 2s/epoch - 5ms/step
# Epoch 86/100
# 341/341 - 1s - loss: 0.1985 - accuracy: 0.9269 - val_loss: 0.1926 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 87/100
# 341/341 - 1s - loss: 0.1913 - accuracy: 0.9301 - val_loss: 0.1883 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 88/100
# 341/341 - 1s - loss: 0.1973 - accuracy: 0.9292 - val_loss: 0.1979 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 89/100
# 341/341 - 1s - loss: 0.2003 - accuracy: 0.9281 - val_loss: 0.1885 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 90/100
# 341/341 - 1s - loss: 0.1924 - accuracy: 0.9309 - val_loss: 0.1857 - val_accuracy: 0.9324 - 1s/epoch - 3ms/step
# Epoch 91/100
# 341/341 - 1s - loss: 0.2000 - accuracy: 0.9262 - val_loss: 0.1914 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 92/100
# 341/341 - 1s - loss: 0.1966 - accuracy: 0.9285 - val_loss: 0.1991 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 93/100
# 341/341 - 1s - loss: 0.1970 - accuracy: 0.9292 - val_loss: 0.1852 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 94/100
# 341/341 - 1s - loss: 0.1987 - accuracy: 0.9287 - val_loss: 0.1877 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 95/100
# 341/341 - 1s - loss: 0.1924 - accuracy: 0.9277 - val_loss: 0.1940 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 96/100
# 341/341 - 2s - loss: 0.1999 - accuracy: 0.9296 - val_loss: 0.1894 - val_accuracy: 0.9280 - 2s/epoch - 5ms/step
# Epoch 97/100
# 341/341 - 1s - loss: 0.1964 - accuracy: 0.9273 - val_loss: 0.1921 - val_accuracy: 0.9313 - 1s/epoch - 3ms/step
# Epoch 98/100
# 341/341 - 1s - loss: 0.1954 - accuracy: 0.9283 - val_loss: 0.1871 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 99/100
# 341/341 - 1s - loss: 0.1930 - accuracy: 0.9311 - val_loss: 0.1870 - val_accuracy: 0.9321 - 1s/epoch - 4ms/step
# Epoch 100/100
# 341/341 - 1s - loss: 0.1963 - accuracy: 0.9326 - val_loss: 0.1874 - val_accuracy: 0.9302 - 1s/epoch - 4ms/step
# ********************************************************
# 86/86 [==============================] - 0s 1ms/step
# Testing ANN Accuracy:  0.9302240176276166
# 341/341 [==============================] - 1s 1ms/step
# Training ANN Accuracy:  0.940025716385011

# %%
# create a sequential model object
model = Sequential()   

# add a dense layer with 100 units, ReLU activation function, and input dimension of 16 to the model
model.add(Dense(100,activation='relu',input_dim=16))
model.add(Dropout(0.2))
model.add(Dense(75,activation='relu'))
# create a sequential model object
model.add(Dropout(0.2))
model.add(Dense(50,activation='relu'))

# create a sequential model object
model.add(Dense(7,activation='softmax'))

#Complie the model
model.compile(loss='sparse_categorical_crossentropy',  # Use sparse categorical cross-entropy as the loss function
              optimizer=Adam(learning_rate=0.001),  # Use Adam optimizer with learning rate of 0.001
              metrics=['accuracy'])  # Track accuracy as the evaluation metric

# %%
# Train the ANN model on the training data for 100 epochs, with a 32 batch size
# Print the training log information for each epoch (verbose=2)
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, verbose=2,validation_data=(X_test,Y_test))

print("********************************************************")

# Use the trained model to make predictions on the testing dataset and calculate the accuracy of testing dataset
y_pred = model.predict(X_test)  # Get predicted class probabilities of the testing dataset
Y_pred = y_pred.argmax(axis=-1) # Convert above probabilities to class labels
test_Accuracy = accuracy_score(Y_test,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Testing ANN Accuracy: ",test_Accuracy)  # Print the testing accuracy

# Use the trained model to make predictions on the training dataset and calculate the accuracy of training dataset
y_pred = model.predict(X_train)   # Get predicted class probabilities of the training dataset
Y_pred = y_pred.argmax(axis=-1)   # Convert above probabilities to class labels
train_Accuracy = accuracy_score(Y_train,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Training ANN Accuracy: ",train_Accuracy)  # Print the testing accuracy
# Out:
# Epoch 1/100
# 341/341 - 3s - loss: 0.4875 - accuracy: 0.8344 - val_loss: 0.2190 - val_accuracy: 0.9214 - 3s/epoch - 9ms/step
# Epoch 2/100
# 341/341 - 1s - loss: 0.2569 - accuracy: 0.9110 - val_loss: 0.2225 - val_accuracy: 0.9207 - 1s/epoch - 4ms/step
# Epoch 3/100
# 341/341 - 1s - loss: 0.2413 - accuracy: 0.9140 - val_loss: 0.2046 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 4/100
# 341/341 - 1s - loss: 0.2323 - accuracy: 0.9186 - val_loss: 0.1968 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 5/100
# 341/341 - 1s - loss: 0.2256 - accuracy: 0.9191 - val_loss: 0.1999 - val_accuracy: 0.9225 - 1s/epoch - 3ms/step
# Epoch 6/100
# 341/341 - 1s - loss: 0.2174 - accuracy: 0.9219 - val_loss: 0.1958 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 7/100
# 341/341 - 1s - loss: 0.2181 - accuracy: 0.9229 - val_loss: 0.2117 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 8/100
# 341/341 - 1s - loss: 0.2116 - accuracy: 0.9222 - val_loss: 0.2014 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# Epoch 9/100
# 341/341 - 1s - loss: 0.2105 - accuracy: 0.9237 - val_loss: 0.1922 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 10/100
# 341/341 - 1s - loss: 0.2121 - accuracy: 0.9240 - val_loss: 0.1959 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 11/100
# 341/341 - 1s - loss: 0.2061 - accuracy: 0.9256 - val_loss: 0.1874 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 12/100
# 341/341 - 1s - loss: 0.2068 - accuracy: 0.9255 - val_loss: 0.1863 - val_accuracy: 0.9291 - 1s/epoch - 4ms/step
# Epoch 13/100
# 341/341 - 1s - loss: 0.2029 - accuracy: 0.9247 - val_loss: 0.1922 - val_accuracy: 0.9291 - 1s/epoch - 4ms/step
# Epoch 14/100
# 341/341 - 1s - loss: 0.2041 - accuracy: 0.9273 - val_loss: 0.1914 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 15/100
# 341/341 - 1s - loss: 0.1992 - accuracy: 0.9285 - val_loss: 0.1912 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 16/100
# 341/341 - 1s - loss: 0.2008 - accuracy: 0.9274 - val_loss: 0.1830 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 17/100
# 341/341 - 1s - loss: 0.1966 - accuracy: 0.9262 - val_loss: 0.1898 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 18/100
# 341/341 - 1s - loss: 0.1978 - accuracy: 0.9260 - val_loss: 0.1892 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 19/100
# 341/341 - 1s - loss: 0.2004 - accuracy: 0.9296 - val_loss: 0.1933 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 20/100
# 341/341 - 1s - loss: 0.1968 - accuracy: 0.9286 - val_loss: 0.1899 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 21/100
# 341/341 - 1s - loss: 0.1957 - accuracy: 0.9276 - val_loss: 0.1876 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 22/100
# 341/341 - 1s - loss: 0.1963 - accuracy: 0.9254 - val_loss: 0.1936 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 23/100
# 341/341 - 1s - loss: 0.1940 - accuracy: 0.9308 - val_loss: 0.1920 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 24/100
# 341/341 - 1s - loss: 0.1949 - accuracy: 0.9296 - val_loss: 0.1885 - val_accuracy: 0.9313 - 1s/epoch - 4ms/step
# Epoch 25/100
# 341/341 - 1s - loss: 0.1930 - accuracy: 0.9307 - val_loss: 0.2076 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 26/100
# 341/341 - 1s - loss: 0.1896 - accuracy: 0.9294 - val_loss: 0.1864 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 27/100
# 341/341 - 1s - loss: 0.1926 - accuracy: 0.9293 - val_loss: 0.1897 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 28/100
# 341/341 - 1s - loss: 0.1916 - accuracy: 0.9314 - val_loss: 0.2035 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 29/100
# 341/341 - 1s - loss: 0.1902 - accuracy: 0.9287 - val_loss: 0.2102 - val_accuracy: 0.9221 - 1s/epoch - 3ms/step
# Epoch 30/100
# 341/341 - 1s - loss: 0.1899 - accuracy: 0.9293 - val_loss: 0.1848 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 31/100
# 341/341 - 1s - loss: 0.1872 - accuracy: 0.9295 - val_loss: 0.1883 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 32/100
# 341/341 - 1s - loss: 0.1837 - accuracy: 0.9333 - val_loss: 0.1888 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 33/100
# 341/341 - 1s - loss: 0.1825 - accuracy: 0.9321 - val_loss: 0.1996 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 34/100
# 341/341 - 2s - loss: 0.1883 - accuracy: 0.9298 - val_loss: 0.1905 - val_accuracy: 0.9310 - 2s/epoch - 4ms/step
# Epoch 35/100
# 341/341 - 1s - loss: 0.1860 - accuracy: 0.9289 - val_loss: 0.1870 - val_accuracy: 0.9273 - 1s/epoch - 4ms/step
# Epoch 36/100
# 341/341 - 1s - loss: 0.1829 - accuracy: 0.9294 - val_loss: 0.1848 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 37/100
# 341/341 - 1s - loss: 0.1884 - accuracy: 0.9316 - val_loss: 0.1944 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 38/100
# 341/341 - 1s - loss: 0.1863 - accuracy: 0.9313 - val_loss: 0.1871 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 39/100
# 341/341 - 1s - loss: 0.1836 - accuracy: 0.9325 - val_loss: 0.1878 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 40/100
# 341/341 - 1s - loss: 0.1812 - accuracy: 0.9331 - val_loss: 0.1911 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 41/100
# 341/341 - 1s - loss: 0.1836 - accuracy: 0.9298 - val_loss: 0.1860 - val_accuracy: 0.9343 - 1s/epoch - 3ms/step
# Epoch 42/100
# 341/341 - 1s - loss: 0.1795 - accuracy: 0.9333 - val_loss: 0.1877 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 43/100
# 341/341 - 1s - loss: 0.1833 - accuracy: 0.9321 - val_loss: 0.1866 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 44/100
# 341/341 - 1s - loss: 0.1785 - accuracy: 0.9329 - val_loss: 0.1866 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 45/100
# 341/341 - 1s - loss: 0.1813 - accuracy: 0.9318 - val_loss: 0.1890 - val_accuracy: 0.9317 - 1s/epoch - 4ms/step
# Epoch 46/100
# 341/341 - 1s - loss: 0.1796 - accuracy: 0.9344 - val_loss: 0.1890 - val_accuracy: 0.9306 - 1s/epoch - 4ms/step
# Epoch 47/100
# 341/341 - 1s - loss: 0.1746 - accuracy: 0.9341 - val_loss: 0.1932 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 48/100
# 341/341 - 1s - loss: 0.1823 - accuracy: 0.9319 - val_loss: 0.1920 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 49/100
# 341/341 - 1s - loss: 0.1808 - accuracy: 0.9319 - val_loss: 0.1954 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 50/100
# 341/341 - 1s - loss: 0.1762 - accuracy: 0.9339 - val_loss: 0.1950 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 51/100
# 341/341 - 1s - loss: 0.1789 - accuracy: 0.9335 - val_loss: 0.1905 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 52/100
# 341/341 - 1s - loss: 0.1773 - accuracy: 0.9334 - val_loss: 0.1893 - val_accuracy: 0.9302 - 1s/epoch - 4ms/step
# Epoch 53/100
# 341/341 - 1s - loss: 0.1783 - accuracy: 0.9349 - val_loss: 0.1915 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 54/100
# 341/341 - 1s - loss: 0.1752 - accuracy: 0.9338 - val_loss: 0.1914 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 55/100
# 341/341 - 1s - loss: 0.1751 - accuracy: 0.9343 - val_loss: 0.1902 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 56/100
# 341/341 - 1s - loss: 0.1767 - accuracy: 0.9336 - val_loss: 0.1984 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 57/100
# 341/341 - 1s - loss: 0.1763 - accuracy: 0.9330 - val_loss: 0.1983 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 58/100
# 341/341 - 1s - loss: 0.1751 - accuracy: 0.9352 - val_loss: 0.2019 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 59/100
# 341/341 - 1s - loss: 0.1727 - accuracy: 0.9355 - val_loss: 0.1867 - val_accuracy: 0.9313 - 1s/epoch - 3ms/step
# Epoch 60/100
# 341/341 - 1s - loss: 0.1729 - accuracy: 0.9341 - val_loss: 0.1937 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 61/100
# 341/341 - 1s - loss: 0.1746 - accuracy: 0.9359 - val_loss: 0.1947 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 62/100
# 341/341 - 1s - loss: 0.1683 - accuracy: 0.9379 - val_loss: 0.1920 - val_accuracy: 0.9313 - 1s/epoch - 3ms/step
# Epoch 63/100
# 341/341 - 1s - loss: 0.1736 - accuracy: 0.9340 - val_loss: 0.1956 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 64/100
# 341/341 - 1s - loss: 0.1761 - accuracy: 0.9330 - val_loss: 0.1983 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 65/100
# 341/341 - 1s - loss: 0.1710 - accuracy: 0.9350 - val_loss: 0.1921 - val_accuracy: 0.9328 - 1s/epoch - 3ms/step
# Epoch 66/100
# 341/341 - 1s - loss: 0.1764 - accuracy: 0.9355 - val_loss: 0.1969 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 67/100
# 341/341 - 2s - loss: 0.1702 - accuracy: 0.9343 - val_loss: 0.1971 - val_accuracy: 0.9269 - 2s/epoch - 5ms/step
# Epoch 68/100
# 341/341 - 1s - loss: 0.1675 - accuracy: 0.9352 - val_loss: 0.2018 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 69/100
# 341/341 - 1s - loss: 0.1737 - accuracy: 0.9340 - val_loss: 0.1909 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 70/100
# 341/341 - 1s - loss: 0.1680 - accuracy: 0.9391 - val_loss: 0.2011 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 71/100
# 341/341 - 1s - loss: 0.1720 - accuracy: 0.9359 - val_loss: 0.1881 - val_accuracy: 0.9324 - 1s/epoch - 3ms/step
# Epoch 72/100
# 341/341 - 1s - loss: 0.1687 - accuracy: 0.9370 - val_loss: 0.1971 - val_accuracy: 0.9317 - 1s/epoch - 3ms/step
# Epoch 73/100
# 341/341 - 1s - loss: 0.1734 - accuracy: 0.9342 - val_loss: 0.2050 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 74/100
# 341/341 - 1s - loss: 0.1714 - accuracy: 0.9345 - val_loss: 0.1912 - val_accuracy: 0.9343 - 1s/epoch - 3ms/step
# Epoch 75/100
# 341/341 - 1s - loss: 0.1686 - accuracy: 0.9380 - val_loss: 0.1937 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 76/100
# 341/341 - 1s - loss: 0.1659 - accuracy: 0.9388 - val_loss: 0.1914 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 77/100
# 341/341 - 1s - loss: 0.1678 - accuracy: 0.9356 - val_loss: 0.1924 - val_accuracy: 0.9332 - 1s/epoch - 4ms/step
# Epoch 78/100
# 341/341 - 2s - loss: 0.1694 - accuracy: 0.9349 - val_loss: 0.1930 - val_accuracy: 0.9310 - 2s/epoch - 4ms/step
# Epoch 79/100
# 341/341 - 1s - loss: 0.1649 - accuracy: 0.9372 - val_loss: 0.1925 - val_accuracy: 0.9328 - 1s/epoch - 3ms/step
# Epoch 80/100
# 341/341 - 1s - loss: 0.1641 - accuracy: 0.9367 - val_loss: 0.1969 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 81/100
# 341/341 - 1s - loss: 0.1673 - accuracy: 0.9361 - val_loss: 0.1993 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 82/100
# 341/341 - 1s - loss: 0.1672 - accuracy: 0.9369 - val_loss: 0.1938 - val_accuracy: 0.9310 - 1s/epoch - 4ms/step
# Epoch 83/100
# 341/341 - 1s - loss: 0.1666 - accuracy: 0.9355 - val_loss: 0.1945 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 84/100
# 341/341 - 1s - loss: 0.1675 - accuracy: 0.9369 - val_loss: 0.1931 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 85/100
# 341/341 - 1s - loss: 0.1678 - accuracy: 0.9372 - val_loss: 0.1946 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 86/100
# 341/341 - 1s - loss: 0.1647 - accuracy: 0.9385 - val_loss: 0.2007 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 87/100
# 341/341 - 1s - loss: 0.1665 - accuracy: 0.9357 - val_loss: 0.1995 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 88/100
# 341/341 - 2s - loss: 0.1686 - accuracy: 0.9375 - val_loss: 0.2018 - val_accuracy: 0.9291 - 2s/epoch - 4ms/step
# Epoch 89/100
# 341/341 - 1s - loss: 0.1661 - accuracy: 0.9375 - val_loss: 0.2060 - val_accuracy: 0.9321 - 1s/epoch - 4ms/step
# Epoch 90/100
# 341/341 - 1s - loss: 0.1643 - accuracy: 0.9406 - val_loss: 0.1996 - val_accuracy: 0.9350 - 1s/epoch - 4ms/step
# Epoch 91/100
# 341/341 - 1s - loss: 0.1619 - accuracy: 0.9364 - val_loss: 0.2009 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 92/100
# 341/341 - 1s - loss: 0.1652 - accuracy: 0.9367 - val_loss: 0.1998 - val_accuracy: 0.9328 - 1s/epoch - 3ms/step
# Epoch 93/100
# 341/341 - 1s - loss: 0.1650 - accuracy: 0.9384 - val_loss: 0.2006 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 94/100
# 341/341 - 1s - loss: 0.1641 - accuracy: 0.9358 - val_loss: 0.1935 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 95/100
# 341/341 - 1s - loss: 0.1669 - accuracy: 0.9368 - val_loss: 0.1937 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 96/100
# 341/341 - 1s - loss: 0.1653 - accuracy: 0.9386 - val_loss: 0.1972 - val_accuracy: 0.9299 - 1s/epoch - 4ms/step
# Epoch 97/100
# 341/341 - 1s - loss: 0.1653 - accuracy: 0.9374 - val_loss: 0.2005 - val_accuracy: 0.9328 - 1s/epoch - 3ms/step
# Epoch 98/100
# 341/341 - 1s - loss: 0.1625 - accuracy: 0.9376 - val_loss: 0.1944 - val_accuracy: 0.9306 - 1s/epoch - 4ms/step
# Epoch 99/100
# 341/341 - 1s - loss: 0.1637 - accuracy: 0.9374 - val_loss: 0.1930 - val_accuracy: 0.9306 - 1s/epoch - 4ms/step
# Epoch 100/100
# 341/341 - 1s - loss: 0.1591 - accuracy: 0.9399 - val_loss: 0.1952 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# ********************************************************
# 86/86 [==============================] - 0s 1ms/step
# Testing ANN Accuracy:  0.9291222915901579
# 341/341 [==============================] - 0s 1ms/step
# Training ANN Accuracy:  0.9464548126377663

# %%
# create a sequential model object
model = Sequential()   

# add a dense layer with 100 units, ReLU activation function, and input dimension of 16 to the model
model.add(Dense(100,activation='relu',input_dim=16))
model.add(Dropout(0.2))
model.add(Dense(75,activation='relu'))
# create a sequential model object
model.add(Dropout(0.2))
model.add(Dense(50,activation='relu'))

# create a sequential model object
model.add(Dense(7,activation='softmax'))

#Complie the model
model.compile(loss='sparse_categorical_crossentropy',  # Use sparse categorical cross-entropy as the loss function
              optimizer=Adam(learning_rate=0.005),  # Use Adam optimizer with learning rate of 0.005
              metrics=['accuracy'])  # Track accuracy as the evaluation metric

# %%
# Train the ANN model on the training data for 100 epochs, with a 32 batch size
# Print the training log information for each epoch (verbose=2)
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, verbose=2,validation_data=(X_test,Y_test))

print("********************************************************")

# Use the trained model to make predictions on the testing dataset and calculate the accuracy of testing dataset
y_pred = model.predict(X_test)  # Get predicted class probabilities of the testing dataset
Y_pred = y_pred.argmax(axis=-1) # Convert above probabilities to class labels
test_Accuracy = accuracy_score(Y_test,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Testing ANN Accuracy: ",test_Accuracy)  # Print the testing accuracy

# Use the trained model to make predictions on the training dataset and calculate the accuracy of training dataset
y_pred = model.predict(X_train)   # Get predicted class probabilities of the training dataset
Y_pred = y_pred.argmax(axis=-1)   # Convert above probabilities to class labels
train_Accuracy = accuracy_score(Y_train,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Training ANN Accuracy: ",train_Accuracy)  # Print the testing accuracy
# Out:
# Epoch 1/100
# 341/341 - 3s - loss: 0.3520 - accuracy: 0.8754 - val_loss: 0.2200 - val_accuracy: 0.9185 - 3s/epoch - 8ms/step
# Epoch 2/100
# 341/341 - 1s - loss: 0.2550 - accuracy: 0.9122 - val_loss: 0.2099 - val_accuracy: 0.9232 - 1s/epoch - 4ms/step
# Epoch 3/100
# 341/341 - 1s - loss: 0.2509 - accuracy: 0.9128 - val_loss: 0.2492 - val_accuracy: 0.9060 - 1s/epoch - 4ms/step
# Epoch 4/100
# 341/341 - 1s - loss: 0.2434 - accuracy: 0.9149 - val_loss: 0.2358 - val_accuracy: 0.9170 - 1s/epoch - 3ms/step
# Epoch 5/100
# 341/341 - 1s - loss: 0.2382 - accuracy: 0.9153 - val_loss: 0.2027 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 6/100
# 341/341 - 1s - loss: 0.2365 - accuracy: 0.9182 - val_loss: 0.2456 - val_accuracy: 0.9119 - 1s/epoch - 4ms/step
# Epoch 7/100
# 341/341 - 1s - loss: 0.2250 - accuracy: 0.9187 - val_loss: 0.2243 - val_accuracy: 0.9166 - 1s/epoch - 3ms/step
# Epoch 8/100
# 341/341 - 1s - loss: 0.2269 - accuracy: 0.9188 - val_loss: 0.2092 - val_accuracy: 0.9192 - 1s/epoch - 4ms/step
# Epoch 9/100
# 341/341 - 1s - loss: 0.2303 - accuracy: 0.9176 - val_loss: 0.2090 - val_accuracy: 0.9243 - 1s/epoch - 3ms/step
# Epoch 10/100
# 341/341 - 1s - loss: 0.2284 - accuracy: 0.9213 - val_loss: 0.1999 - val_accuracy: 0.9243 - 1s/epoch - 3ms/step
# Epoch 11/100
# 341/341 - 1s - loss: 0.2213 - accuracy: 0.9230 - val_loss: 0.2031 - val_accuracy: 0.9229 - 1s/epoch - 3ms/step
# Epoch 12/100
# 341/341 - 1s - loss: 0.2214 - accuracy: 0.9227 - val_loss: 0.2040 - val_accuracy: 0.9251 - 1s/epoch - 4ms/step
# Epoch 13/100
# 341/341 - 1s - loss: 0.2163 - accuracy: 0.9231 - val_loss: 0.2126 - val_accuracy: 0.9196 - 1s/epoch - 4ms/step
# Epoch 14/100
# 341/341 - 1s - loss: 0.2190 - accuracy: 0.9221 - val_loss: 0.2038 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 15/100
# 341/341 - 1s - loss: 0.2173 - accuracy: 0.9223 - val_loss: 0.2006 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 16/100
# 341/341 - 1s - loss: 0.2172 - accuracy: 0.9225 - val_loss: 0.2037 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 17/100
# 341/341 - 1s - loss: 0.2203 - accuracy: 0.9212 - val_loss: 0.2129 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 18/100
# 341/341 - 1s - loss: 0.2187 - accuracy: 0.9225 - val_loss: 0.2340 - val_accuracy: 0.9174 - 1s/epoch - 3ms/step
# Epoch 19/100
# 341/341 - 1s - loss: 0.2157 - accuracy: 0.9209 - val_loss: 0.2314 - val_accuracy: 0.9133 - 1s/epoch - 3ms/step
# Epoch 20/100
# 341/341 - 1s - loss: 0.2048 - accuracy: 0.9261 - val_loss: 0.2215 - val_accuracy: 0.9199 - 1s/epoch - 3ms/step
# Epoch 21/100
# 341/341 - 1s - loss: 0.2190 - accuracy: 0.9235 - val_loss: 0.2035 - val_accuracy: 0.9214 - 1s/epoch - 3ms/step
# Epoch 22/100
# 341/341 - 1s - loss: 0.2197 - accuracy: 0.9224 - val_loss: 0.2068 - val_accuracy: 0.9199 - 1s/epoch - 3ms/step
# Epoch 23/100
# 341/341 - 1s - loss: 0.2133 - accuracy: 0.9240 - val_loss: 0.2036 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 24/100
# 341/341 - 1s - loss: 0.2125 - accuracy: 0.9225 - val_loss: 0.1982 - val_accuracy: 0.9240 - 1s/epoch - 4ms/step
# Epoch 25/100
# 341/341 - 1s - loss: 0.2176 - accuracy: 0.9248 - val_loss: 0.2035 - val_accuracy: 0.9254 - 1s/epoch - 4ms/step
# Epoch 26/100
# 341/341 - 1s - loss: 0.2090 - accuracy: 0.9267 - val_loss: 0.2054 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 27/100
# 341/341 - 1s - loss: 0.2051 - accuracy: 0.9261 - val_loss: 0.2047 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 28/100
# 341/341 - 1s - loss: 0.2004 - accuracy: 0.9294 - val_loss: 0.2100 - val_accuracy: 0.9225 - 1s/epoch - 3ms/step
# Epoch 29/100
# 341/341 - 1s - loss: 0.2071 - accuracy: 0.9255 - val_loss: 0.1988 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 30/100
# 341/341 - 1s - loss: 0.2040 - accuracy: 0.9281 - val_loss: 0.2116 - val_accuracy: 0.9207 - 1s/epoch - 4ms/step
# Epoch 31/100
# 341/341 - 1s - loss: 0.2057 - accuracy: 0.9285 - val_loss: 0.1957 - val_accuracy: 0.9258 - 1s/epoch - 4ms/step
# Epoch 32/100
# 341/341 - 1s - loss: 0.2020 - accuracy: 0.9258 - val_loss: 0.2021 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 33/100
# 341/341 - 1s - loss: 0.2010 - accuracy: 0.9290 - val_loss: 0.2005 - val_accuracy: 0.9240 - 1s/epoch - 4ms/step
# Epoch 34/100
# 341/341 - 2s - loss: 0.2027 - accuracy: 0.9273 - val_loss: 0.1959 - val_accuracy: 0.9225 - 2s/epoch - 4ms/step
# Epoch 35/100
# 341/341 - 1s - loss: 0.2097 - accuracy: 0.9262 - val_loss: 0.2042 - val_accuracy: 0.9214 - 1s/epoch - 3ms/step
# Epoch 36/100
# 341/341 - 1s - loss: 0.2020 - accuracy: 0.9271 - val_loss: 0.2089 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 37/100
# 341/341 - 1s - loss: 0.2154 - accuracy: 0.9255 - val_loss: 0.2025 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 38/100
# 341/341 - 1s - loss: 0.2059 - accuracy: 0.9280 - val_loss: 0.2040 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 39/100
# 341/341 - 1s - loss: 0.2014 - accuracy: 0.9263 - val_loss: 0.2072 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 40/100
# 341/341 - 1s - loss: 0.2036 - accuracy: 0.9260 - val_loss: 0.2054 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 41/100
# 341/341 - 1s - loss: 0.2026 - accuracy: 0.9303 - val_loss: 0.2210 - val_accuracy: 0.9207 - 1s/epoch - 3ms/step
# Epoch 42/100
# 341/341 - 1s - loss: 0.2040 - accuracy: 0.9285 - val_loss: 0.2058 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 43/100
# 341/341 - 1s - loss: 0.2054 - accuracy: 0.9268 - val_loss: 0.2121 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 44/100
# 341/341 - 2s - loss: 0.2026 - accuracy: 0.9276 - val_loss: 0.2090 - val_accuracy: 0.9266 - 2s/epoch - 4ms/step
# Epoch 45/100
# 341/341 - 1s - loss: 0.2042 - accuracy: 0.9261 - val_loss: 0.2144 - val_accuracy: 0.9232 - 1s/epoch - 4ms/step
# Epoch 46/100
# 341/341 - 1s - loss: 0.2067 - accuracy: 0.9280 - val_loss: 0.2090 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 47/100
# 341/341 - 1s - loss: 0.2108 - accuracy: 0.9269 - val_loss: 0.2054 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 48/100
# 341/341 - 1s - loss: 0.2061 - accuracy: 0.9263 - val_loss: 0.2053 - val_accuracy: 0.9232 - 1s/epoch - 3ms/step
# Epoch 49/100
# 341/341 - 1s - loss: 0.1971 - accuracy: 0.9296 - val_loss: 0.1946 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 50/100
# 341/341 - 1s - loss: 0.2015 - accuracy: 0.9299 - val_loss: 0.2034 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 51/100
# 341/341 - 1s - loss: 0.2028 - accuracy: 0.9290 - val_loss: 0.2088 - val_accuracy: 0.9218 - 1s/epoch - 3ms/step
# Epoch 52/100
# 341/341 - 1s - loss: 0.2038 - accuracy: 0.9283 - val_loss: 0.2173 - val_accuracy: 0.9225 - 1s/epoch - 3ms/step
# Epoch 53/100
# 341/341 - 1s - loss: 0.1960 - accuracy: 0.9307 - val_loss: 0.2027 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 54/100
# 341/341 - 1s - loss: 0.1953 - accuracy: 0.9290 - val_loss: 0.2066 - val_accuracy: 0.9247 - 1s/epoch - 4ms/step
# Epoch 55/100
# 341/341 - 1s - loss: 0.1986 - accuracy: 0.9267 - val_loss: 0.2101 - val_accuracy: 0.9269 - 1s/epoch - 4ms/step
# Epoch 56/100
# 341/341 - 1s - loss: 0.1999 - accuracy: 0.9297 - val_loss: 0.2065 - val_accuracy: 0.9240 - 1s/epoch - 3ms/step
# Epoch 57/100
# 341/341 - 1s - loss: 0.2062 - accuracy: 0.9246 - val_loss: 0.2098 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 58/100
# 341/341 - 1s - loss: 0.1894 - accuracy: 0.9296 - val_loss: 0.2047 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 59/100
# 341/341 - 1s - loss: 0.1986 - accuracy: 0.9289 - val_loss: 0.2000 - val_accuracy: 0.9243 - 1s/epoch - 3ms/step
# Epoch 60/100
# 341/341 - 1s - loss: 0.2016 - accuracy: 0.9291 - val_loss: 0.2069 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 61/100
# 341/341 - 1s - loss: 0.2078 - accuracy: 0.9253 - val_loss: 0.2006 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 62/100
# 341/341 - 1s - loss: 0.2027 - accuracy: 0.9291 - val_loss: 0.2055 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 63/100
# 341/341 - 1s - loss: 0.1983 - accuracy: 0.9284 - val_loss: 0.2056 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 64/100
# 341/341 - 1s - loss: 0.1959 - accuracy: 0.9286 - val_loss: 0.2043 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 65/100
# 341/341 - 1s - loss: 0.1950 - accuracy: 0.9303 - val_loss: 0.1939 - val_accuracy: 0.9302 - 1s/epoch - 4ms/step
# Epoch 66/100
# 341/341 - 1s - loss: 0.1936 - accuracy: 0.9281 - val_loss: 0.1989 - val_accuracy: 0.9266 - 1s/epoch - 4ms/step
# Epoch 67/100
# 341/341 - 1s - loss: 0.1976 - accuracy: 0.9307 - val_loss: 0.2209 - val_accuracy: 0.9203 - 1s/epoch - 3ms/step
# Epoch 68/100
# 341/341 - 1s - loss: 0.1997 - accuracy: 0.9274 - val_loss: 0.2047 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 69/100
# 341/341 - 1s - loss: 0.1990 - accuracy: 0.9274 - val_loss: 0.2024 - val_accuracy: 0.9251 - 1s/epoch - 4ms/step
# Epoch 70/100
# 341/341 - 1s - loss: 0.1935 - accuracy: 0.9271 - val_loss: 0.2077 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 71/100
# 341/341 - 1s - loss: 0.1935 - accuracy: 0.9296 - val_loss: 0.1950 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 72/100
# 341/341 - 1s - loss: 0.1888 - accuracy: 0.9324 - val_loss: 0.2096 - val_accuracy: 0.9221 - 1s/epoch - 4ms/step
# Epoch 73/100
# 341/341 - 1s - loss: 0.1971 - accuracy: 0.9310 - val_loss: 0.1986 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 74/100
# 341/341 - 1s - loss: 0.1934 - accuracy: 0.9317 - val_loss: 0.1983 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 75/100
# 341/341 - 1s - loss: 0.1983 - accuracy: 0.9299 - val_loss: 0.1960 - val_accuracy: 0.9254 - 1s/epoch - 4ms/step
# Epoch 76/100
# 341/341 - 1s - loss: 0.2007 - accuracy: 0.9295 - val_loss: 0.2120 - val_accuracy: 0.9221 - 1s/epoch - 4ms/step
# Epoch 77/100
# 341/341 - 1s - loss: 0.2031 - accuracy: 0.9286 - val_loss: 0.2080 - val_accuracy: 0.9225 - 1s/epoch - 3ms/step
# Epoch 78/100
# 341/341 - 1s - loss: 0.1951 - accuracy: 0.9319 - val_loss: 0.2090 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 79/100
# 341/341 - 1s - loss: 0.1977 - accuracy: 0.9284 - val_loss: 0.1991 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 80/100
# 341/341 - 1s - loss: 0.1942 - accuracy: 0.9309 - val_loss: 0.2029 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 81/100
# 341/341 - 1s - loss: 0.1970 - accuracy: 0.9286 - val_loss: 0.1999 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 82/100
# 341/341 - 1s - loss: 0.1970 - accuracy: 0.9305 - val_loss: 0.2051 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 83/100
# 341/341 - 1s - loss: 0.1886 - accuracy: 0.9334 - val_loss: 0.1947 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 84/100
# 341/341 - 1s - loss: 0.1985 - accuracy: 0.9296 - val_loss: 0.2002 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 85/100
# 341/341 - 1s - loss: 0.1923 - accuracy: 0.9303 - val_loss: 0.2066 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 86/100
# 341/341 - 1s - loss: 0.1842 - accuracy: 0.9343 - val_loss: 0.2002 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 87/100
# 341/341 - 1s - loss: 0.2018 - accuracy: 0.9278 - val_loss: 0.1974 - val_accuracy: 0.9306 - 1s/epoch - 4ms/step
# Epoch 88/100
# 341/341 - 1s - loss: 0.2025 - accuracy: 0.9278 - val_loss: 0.2018 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 89/100
# 341/341 - 1s - loss: 0.2054 - accuracy: 0.9296 - val_loss: 0.2035 - val_accuracy: 0.9269 - 1s/epoch - 4ms/step
# Epoch 90/100
# 341/341 - 1s - loss: 0.1916 - accuracy: 0.9289 - val_loss: 0.2161 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 91/100
# 341/341 - 1s - loss: 0.2090 - accuracy: 0.9285 - val_loss: 0.1961 - val_accuracy: 0.9310 - 1s/epoch - 4ms/step
# Epoch 92/100
# 341/341 - 1s - loss: 0.1987 - accuracy: 0.9258 - val_loss: 0.2002 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 93/100
# 341/341 - 1s - loss: 0.1924 - accuracy: 0.9290 - val_loss: 0.2035 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 94/100
# 341/341 - 1s - loss: 0.1994 - accuracy: 0.9284 - val_loss: 0.2058 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 95/100
# 341/341 - 1s - loss: 0.2143 - accuracy: 0.9276 - val_loss: 0.1985 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 96/100
# 341/341 - 1s - loss: 0.1934 - accuracy: 0.9331 - val_loss: 0.2058 - val_accuracy: 0.9262 - 1s/epoch - 4ms/step
# Epoch 97/100
# 341/341 - 2s - loss: 0.1876 - accuracy: 0.9280 - val_loss: 0.2125 - val_accuracy: 0.9251 - 2s/epoch - 4ms/step
# Epoch 98/100
# 341/341 - 1s - loss: 0.1906 - accuracy: 0.9318 - val_loss: 0.2039 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 99/100
# 341/341 - 1s - loss: 0.1879 - accuracy: 0.9306 - val_loss: 0.2074 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 100/100
# 341/341 - 1s - loss: 0.1841 - accuracy: 0.9315 - val_loss: 0.1986 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# ********************************************************
# 86/86 [==============================] - 0s 1ms/step
# Testing ANN Accuracy:  0.9254498714652957
# 341/341 [==============================] - 1s 1ms/step
# Training ANN Accuracy:  0.9382806759735489

# %%
# create a sequential model object
model = Sequential()   

# add a dense layer with 100 units, ReLU activation function, and input dimension of 16 to the model
model.add(Dense(100,activation='relu',input_dim=16))
model.add(Dropout(0.2))
model.add(Dense(75,activation='relu'))
# create a sequential model object
model.add(Dropout(0.2))
model.add(Dense(50,activation='relu'))

# create a sequential model object
model.add(Dense(7,activation='softmax'))

#Complie the model
model.compile(loss='sparse_categorical_crossentropy',  # Use sparse categorical cross-entropy as the loss function
              optimizer=Adam(learning_rate=0.001),  # Use Adam optimizer with learning rate of 0.001
              metrics=['accuracy'])  # Track accuracy as the evaluation metric

# %%
# Train the ANN model on the training data for 100 epochs, with a 32 batch size
# Print the training log information for each epoch (verbose=2)
history = model.fit(X_train, Y_train, epochs=200, batch_size=32, verbose=2,validation_data=(X_test,Y_test))

print("********************************************************")

# Use the trained model to make predictions on the testing dataset and calculate the accuracy of testing dataset
y_pred = model.predict(X_test)  # Get predicted class probabilities of the testing dataset
Y_pred = y_pred.argmax(axis=-1) # Convert above probabilities to class labels
test_Accuracy = accuracy_score(Y_test,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Testing ANN Accuracy: ",test_Accuracy)  # Print the testing accuracy

# Use the trained model to make predictions on the training dataset and calculate the accuracy of training dataset
y_pred = model.predict(X_train)   # Get predicted class probabilities of the training dataset
Y_pred = y_pred.argmax(axis=-1)   # Convert above probabilities to class labels
train_Accuracy = accuracy_score(Y_train,Y_pred)  # Calculate accuracy of predicted labels compared to actual labels
print("Training ANN Accuracy: ",train_Accuracy)  # Print the testing accuracy
# Out:
# Epoch 1/200
# 341/341 - 3s - loss: 0.5278 - accuracy: 0.8136 - val_loss: 0.2333 - val_accuracy: 0.9166 - 3s/epoch - 8ms/step
# Epoch 2/200
# 341/341 - 1s - loss: 0.2680 - accuracy: 0.9069 - val_loss: 0.2091 - val_accuracy: 0.9207 - 1s/epoch - 4ms/step
# Epoch 3/200
# 341/341 - 2s - loss: 0.2403 - accuracy: 0.9146 - val_loss: 0.2045 - val_accuracy: 0.9203 - 2s/epoch - 5ms/step
# Epoch 4/200
# 341/341 - 1s - loss: 0.2343 - accuracy: 0.9176 - val_loss: 0.2084 - val_accuracy: 0.9196 - 1s/epoch - 4ms/step
# Epoch 5/200
# 341/341 - 1s - loss: 0.2248 - accuracy: 0.9188 - val_loss: 0.1939 - val_accuracy: 0.9258 - 1s/epoch - 4ms/step
# Epoch 6/200
# 341/341 - 1s - loss: 0.2213 - accuracy: 0.9207 - val_loss: 0.1977 - val_accuracy: 0.9236 - 1s/epoch - 3ms/step
# Epoch 7/200
# 341/341 - 1s - loss: 0.2132 - accuracy: 0.9237 - val_loss: 0.2022 - val_accuracy: 0.9221 - 1s/epoch - 3ms/step
# Epoch 8/200
# 341/341 - 1s - loss: 0.2146 - accuracy: 0.9227 - val_loss: 0.2053 - val_accuracy: 0.9214 - 1s/epoch - 3ms/step
# Epoch 9/200
# 341/341 - 1s - loss: 0.2108 - accuracy: 0.9242 - val_loss: 0.2039 - val_accuracy: 0.9196 - 1s/epoch - 4ms/step
# Epoch 10/200
# 341/341 - 1s - loss: 0.2098 - accuracy: 0.9236 - val_loss: 0.2002 - val_accuracy: 0.9243 - 1s/epoch - 4ms/step
# Epoch 11/200
# 341/341 - 1s - loss: 0.2068 - accuracy: 0.9251 - val_loss: 0.1947 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 12/200
# 341/341 - 1s - loss: 0.2050 - accuracy: 0.9262 - val_loss: 0.2065 - val_accuracy: 0.9262 - 1s/epoch - 4ms/step
# Epoch 13/200
# 341/341 - 1s - loss: 0.2072 - accuracy: 0.9245 - val_loss: 0.1995 - val_accuracy: 0.9240 - 1s/epoch - 4ms/step
# Epoch 14/200
# 341/341 - 1s - loss: 0.2031 - accuracy: 0.9261 - val_loss: 0.1922 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# Epoch 15/200
# 341/341 - 1s - loss: 0.2040 - accuracy: 0.9253 - val_loss: 0.1989 - val_accuracy: 0.9240 - 1s/epoch - 4ms/step
# Epoch 16/200
# 341/341 - 1s - loss: 0.1988 - accuracy: 0.9285 - val_loss: 0.1976 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 17/200
# 341/341 - 1s - loss: 0.1991 - accuracy: 0.9255 - val_loss: 0.1881 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 18/200
# 341/341 - 1s - loss: 0.1987 - accuracy: 0.9286 - val_loss: 0.1892 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 19/200
# 341/341 - 1s - loss: 0.1983 - accuracy: 0.9268 - val_loss: 0.1993 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 20/200
# 341/341 - 1s - loss: 0.2009 - accuracy: 0.9263 - val_loss: 0.1902 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 21/200
# 341/341 - 1s - loss: 0.1994 - accuracy: 0.9274 - val_loss: 0.2009 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 22/200
# 341/341 - 1s - loss: 0.1973 - accuracy: 0.9280 - val_loss: 0.1880 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 23/200
# 341/341 - 1s - loss: 0.1937 - accuracy: 0.9293 - val_loss: 0.1852 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 24/200
# 341/341 - 1s - loss: 0.1937 - accuracy: 0.9288 - val_loss: 0.1841 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 25/200
# 341/341 - 1s - loss: 0.1961 - accuracy: 0.9272 - val_loss: 0.1885 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 26/200
# 341/341 - 1s - loss: 0.1883 - accuracy: 0.9274 - val_loss: 0.1896 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 27/200
# 341/341 - 1s - loss: 0.1951 - accuracy: 0.9283 - val_loss: 0.1894 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 28/200
# 341/341 - 1s - loss: 0.1928 - accuracy: 0.9307 - val_loss: 0.1929 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 29/200
# 341/341 - 1s - loss: 0.1875 - accuracy: 0.9301 - val_loss: 0.1910 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 30/200
# 341/341 - 1s - loss: 0.1904 - accuracy: 0.9286 - val_loss: 0.1858 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 31/200
# 341/341 - 1s - loss: 0.1866 - accuracy: 0.9313 - val_loss: 0.1847 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 32/200
# 341/341 - 1s - loss: 0.1875 - accuracy: 0.9303 - val_loss: 0.1892 - val_accuracy: 0.9251 - 1s/epoch - 3ms/step
# Epoch 33/200
# 341/341 - 1s - loss: 0.1867 - accuracy: 0.9307 - val_loss: 0.1825 - val_accuracy: 0.9299 - 1s/epoch - 4ms/step
# Epoch 34/200
# 341/341 - 1s - loss: 0.1870 - accuracy: 0.9329 - val_loss: 0.1910 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 35/200
# 341/341 - 1s - loss: 0.1856 - accuracy: 0.9319 - val_loss: 0.1873 - val_accuracy: 0.9313 - 1s/epoch - 4ms/step
# Epoch 36/200
# 341/341 - 1s - loss: 0.1852 - accuracy: 0.9303 - val_loss: 0.1959 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# Epoch 37/200
# 341/341 - 1s - loss: 0.1849 - accuracy: 0.9304 - val_loss: 0.1886 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 38/200
# 341/341 - 1s - loss: 0.1865 - accuracy: 0.9319 - val_loss: 0.1852 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 39/200
# 341/341 - 1s - loss: 0.1808 - accuracy: 0.9314 - val_loss: 0.1960 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# Epoch 40/200
# 341/341 - 1s - loss: 0.1870 - accuracy: 0.9306 - val_loss: 0.1905 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 41/200
# 341/341 - 1s - loss: 0.1814 - accuracy: 0.9291 - val_loss: 0.1962 - val_accuracy: 0.9273 - 1s/epoch - 4ms/step
# Epoch 42/200
# 341/341 - 1s - loss: 0.1833 - accuracy: 0.9333 - val_loss: 0.1940 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 43/200
# 341/341 - 1s - loss: 0.1798 - accuracy: 0.9340 - val_loss: 0.1865 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 44/200
# 341/341 - 1s - loss: 0.1798 - accuracy: 0.9322 - val_loss: 0.1944 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 45/200
# 341/341 - 2s - loss: 0.1794 - accuracy: 0.9324 - val_loss: 0.1914 - val_accuracy: 0.9291 - 2s/epoch - 4ms/step
# Epoch 46/200
# 341/341 - 1s - loss: 0.1810 - accuracy: 0.9302 - val_loss: 0.1935 - val_accuracy: 0.9262 - 1s/epoch - 4ms/step
# Epoch 47/200
# 341/341 - 1s - loss: 0.1795 - accuracy: 0.9337 - val_loss: 0.1859 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 48/200
# 341/341 - 1s - loss: 0.1784 - accuracy: 0.9345 - val_loss: 0.1839 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 49/200
# 341/341 - 1s - loss: 0.1824 - accuracy: 0.9309 - val_loss: 0.1901 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 50/200
# 341/341 - 1s - loss: 0.1755 - accuracy: 0.9352 - val_loss: 0.1885 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 51/200
# 341/341 - 1s - loss: 0.1767 - accuracy: 0.9320 - val_loss: 0.1897 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 52/200
# 341/341 - 1s - loss: 0.1777 - accuracy: 0.9332 - val_loss: 0.1882 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 53/200
# 341/341 - 1s - loss: 0.1778 - accuracy: 0.9324 - val_loss: 0.1879 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 54/200
# 341/341 - 1s - loss: 0.1753 - accuracy: 0.9344 - val_loss: 0.1930 - val_accuracy: 0.9302 - 1s/epoch - 4ms/step
# Epoch 55/200
# 341/341 - 1s - loss: 0.1782 - accuracy: 0.9329 - val_loss: 0.1890 - val_accuracy: 0.9302 - 1s/epoch - 4ms/step
# Epoch 56/200
# 341/341 - 2s - loss: 0.1757 - accuracy: 0.9333 - val_loss: 0.1898 - val_accuracy: 0.9310 - 2s/epoch - 5ms/step
# Epoch 57/200
# 341/341 - 1s - loss: 0.1753 - accuracy: 0.9341 - val_loss: 0.1903 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 58/200
# 341/341 - 1s - loss: 0.1762 - accuracy: 0.9340 - val_loss: 0.1910 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 59/200
# 341/341 - 1s - loss: 0.1752 - accuracy: 0.9318 - val_loss: 0.1931 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 60/200
# 341/341 - 1s - loss: 0.1742 - accuracy: 0.9334 - val_loss: 0.1892 - val_accuracy: 0.9317 - 1s/epoch - 3ms/step
# Epoch 61/200
# 341/341 - 1s - loss: 0.1760 - accuracy: 0.9343 - val_loss: 0.1883 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 62/200
# 341/341 - 1s - loss: 0.1713 - accuracy: 0.9343 - val_loss: 0.1901 - val_accuracy: 0.9302 - 1s/epoch - 4ms/step
# Epoch 63/200
# 341/341 - 1s - loss: 0.1719 - accuracy: 0.9354 - val_loss: 0.1929 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 64/200
# 341/341 - 1s - loss: 0.1715 - accuracy: 0.9327 - val_loss: 0.1886 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 65/200
# 341/341 - 1s - loss: 0.1709 - accuracy: 0.9331 - val_loss: 0.1960 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 66/200
# 341/341 - 1s - loss: 0.1740 - accuracy: 0.9344 - val_loss: 0.1920 - val_accuracy: 0.9302 - 1s/epoch - 4ms/step
# Epoch 67/200
# 341/341 - 1s - loss: 0.1688 - accuracy: 0.9347 - val_loss: 0.1936 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 68/200
# 341/341 - 1s - loss: 0.1710 - accuracy: 0.9349 - val_loss: 0.1945 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 69/200
# 341/341 - 1s - loss: 0.1721 - accuracy: 0.9362 - val_loss: 0.1981 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 70/200
# 341/341 - 1s - loss: 0.1719 - accuracy: 0.9343 - val_loss: 0.1911 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 71/200
# 341/341 - 1s - loss: 0.1718 - accuracy: 0.9351 - val_loss: 0.1928 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 72/200
# 341/341 - 1s - loss: 0.1678 - accuracy: 0.9361 - val_loss: 0.1933 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 73/200
# 341/341 - 1s - loss: 0.1743 - accuracy: 0.9337 - val_loss: 0.1851 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 74/200
# 341/341 - 1s - loss: 0.1711 - accuracy: 0.9341 - val_loss: 0.1880 - val_accuracy: 0.9313 - 1s/epoch - 3ms/step
# Epoch 75/200
# 341/341 - 1s - loss: 0.1680 - accuracy: 0.9358 - val_loss: 0.1961 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 76/200
# 341/341 - 1s - loss: 0.1735 - accuracy: 0.9357 - val_loss: 0.1956 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 77/200
# 341/341 - 1s - loss: 0.1669 - accuracy: 0.9367 - val_loss: 0.1868 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 78/200
# 341/341 - 1s - loss: 0.1667 - accuracy: 0.9368 - val_loss: 0.1882 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 79/200
# 341/341 - 1s - loss: 0.1695 - accuracy: 0.9341 - val_loss: 0.1931 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 80/200
# 341/341 - 1s - loss: 0.1644 - accuracy: 0.9364 - val_loss: 0.1952 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 81/200
# 341/341 - 1s - loss: 0.1681 - accuracy: 0.9391 - val_loss: 0.2043 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 82/200
# 341/341 - 1s - loss: 0.1677 - accuracy: 0.9364 - val_loss: 0.1893 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 83/200
# 341/341 - 1s - loss: 0.1669 - accuracy: 0.9366 - val_loss: 0.1985 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 84/200
# 341/341 - 1s - loss: 0.1670 - accuracy: 0.9366 - val_loss: 0.2049 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 85/200
# 341/341 - 1s - loss: 0.1692 - accuracy: 0.9352 - val_loss: 0.1928 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 86/200
# 341/341 - 1s - loss: 0.1693 - accuracy: 0.9348 - val_loss: 0.1893 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 87/200
# 341/341 - 1s - loss: 0.1635 - accuracy: 0.9364 - val_loss: 0.1933 - val_accuracy: 0.9284 - 1s/epoch - 4ms/step
# Epoch 88/200
# 341/341 - 2s - loss: 0.1667 - accuracy: 0.9369 - val_loss: 0.1979 - val_accuracy: 0.9288 - 2s/epoch - 4ms/step
# Epoch 89/200
# 341/341 - 1s - loss: 0.1657 - accuracy: 0.9352 - val_loss: 0.1924 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 90/200
# 341/341 - 1s - loss: 0.1649 - accuracy: 0.9380 - val_loss: 0.1916 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 91/200
# 341/341 - 1s - loss: 0.1652 - accuracy: 0.9368 - val_loss: 0.1928 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 92/200
# 341/341 - 1s - loss: 0.1616 - accuracy: 0.9381 - val_loss: 0.1938 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 93/200
# 341/341 - 1s - loss: 0.1639 - accuracy: 0.9393 - val_loss: 0.1962 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 94/200
# 341/341 - 1s - loss: 0.1620 - accuracy: 0.9362 - val_loss: 0.1977 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 95/200
# 341/341 - 1s - loss: 0.1667 - accuracy: 0.9347 - val_loss: 0.1948 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 96/200
# 341/341 - 1s - loss: 0.1616 - accuracy: 0.9366 - val_loss: 0.1899 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 97/200
# 341/341 - 1s - loss: 0.1640 - accuracy: 0.9381 - val_loss: 0.1946 - val_accuracy: 0.9291 - 1s/epoch - 4ms/step
# Epoch 98/200
# 341/341 - 1s - loss: 0.1658 - accuracy: 0.9378 - val_loss: 0.1963 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 99/200
# 341/341 - 2s - loss: 0.1630 - accuracy: 0.9383 - val_loss: 0.1935 - val_accuracy: 0.9284 - 2s/epoch - 4ms/step
# Epoch 100/200
# 341/341 - 1s - loss: 0.1655 - accuracy: 0.9366 - val_loss: 0.1989 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 101/200
# 341/341 - 1s - loss: 0.1636 - accuracy: 0.9383 - val_loss: 0.1994 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 102/200
# 341/341 - 1s - loss: 0.1618 - accuracy: 0.9391 - val_loss: 0.1922 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 103/200
# 341/341 - 1s - loss: 0.1630 - accuracy: 0.9376 - val_loss: 0.1953 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 104/200
# 341/341 - 1s - loss: 0.1630 - accuracy: 0.9386 - val_loss: 0.1918 - val_accuracy: 0.9328 - 1s/epoch - 3ms/step
# Epoch 105/200
# 341/341 - 1s - loss: 0.1597 - accuracy: 0.9376 - val_loss: 0.1959 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 106/200
# 341/341 - 1s - loss: 0.1628 - accuracy: 0.9392 - val_loss: 0.1951 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 107/200
# 341/341 - 1s - loss: 0.1610 - accuracy: 0.9398 - val_loss: 0.2018 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 108/200
# 341/341 - 2s - loss: 0.1607 - accuracy: 0.9396 - val_loss: 0.1909 - val_accuracy: 0.9299 - 2s/epoch - 5ms/step
# Epoch 109/200
# 341/341 - 2s - loss: 0.1576 - accuracy: 0.9387 - val_loss: 0.1959 - val_accuracy: 0.9288 - 2s/epoch - 5ms/step
# Epoch 110/200
# 341/341 - 1s - loss: 0.1581 - accuracy: 0.9381 - val_loss: 0.1973 - val_accuracy: 0.9310 - 1s/epoch - 4ms/step
# Epoch 111/200
# 341/341 - 1s - loss: 0.1607 - accuracy: 0.9407 - val_loss: 0.2021 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 112/200
# 341/341 - 1s - loss: 0.1581 - accuracy: 0.9383 - val_loss: 0.1928 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 113/200
# 341/341 - 1s - loss: 0.1623 - accuracy: 0.9375 - val_loss: 0.1964 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 114/200
# 341/341 - 1s - loss: 0.1607 - accuracy: 0.9373 - val_loss: 0.1973 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 115/200
# 341/341 - 1s - loss: 0.1592 - accuracy: 0.9378 - val_loss: 0.2032 - val_accuracy: 0.9258 - 1s/epoch - 3ms/step
# Epoch 116/200
# 341/341 - 1s - loss: 0.1583 - accuracy: 0.9391 - val_loss: 0.1974 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 117/200
# 341/341 - 1s - loss: 0.1592 - accuracy: 0.9420 - val_loss: 0.1961 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 118/200
# 341/341 - 1s - loss: 0.1566 - accuracy: 0.9399 - val_loss: 0.1955 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 119/200
# 341/341 - 1s - loss: 0.1602 - accuracy: 0.9390 - val_loss: 0.1954 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 120/200
# 341/341 - 2s - loss: 0.1611 - accuracy: 0.9384 - val_loss: 0.2062 - val_accuracy: 0.9247 - 2s/epoch - 5ms/step
# Epoch 121/200
# 341/341 - 1s - loss: 0.1553 - accuracy: 0.9396 - val_loss: 0.2033 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 122/200
# 341/341 - 1s - loss: 0.1583 - accuracy: 0.9381 - val_loss: 0.2022 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 123/200
# 341/341 - 1s - loss: 0.1618 - accuracy: 0.9379 - val_loss: 0.2012 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 124/200
# 341/341 - 1s - loss: 0.1587 - accuracy: 0.9385 - val_loss: 0.1984 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 125/200
# 341/341 - 1s - loss: 0.1570 - accuracy: 0.9405 - val_loss: 0.2022 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 126/200
# 341/341 - 1s - loss: 0.1565 - accuracy: 0.9378 - val_loss: 0.2017 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 127/200
# 341/341 - 1s - loss: 0.1571 - accuracy: 0.9389 - val_loss: 0.2037 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 128/200
# 341/341 - 1s - loss: 0.1590 - accuracy: 0.9392 - val_loss: 0.2011 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 129/200
# 341/341 - 1s - loss: 0.1552 - accuracy: 0.9407 - val_loss: 0.2073 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 130/200
# 341/341 - 1s - loss: 0.1528 - accuracy: 0.9406 - val_loss: 0.2160 - val_accuracy: 0.9236 - 1s/epoch - 4ms/step
# Epoch 131/200
# 341/341 - 2s - loss: 0.1569 - accuracy: 0.9388 - val_loss: 0.2083 - val_accuracy: 0.9262 - 2s/epoch - 4ms/step
# Epoch 132/200
# 341/341 - 1s - loss: 0.1553 - accuracy: 0.9387 - val_loss: 0.1957 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 133/200
# 341/341 - 1s - loss: 0.1515 - accuracy: 0.9409 - val_loss: 0.2001 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 134/200
# 341/341 - 1s - loss: 0.1546 - accuracy: 0.9415 - val_loss: 0.2038 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 135/200
# 341/341 - 1s - loss: 0.1576 - accuracy: 0.9397 - val_loss: 0.2020 - val_accuracy: 0.9247 - 1s/epoch - 3ms/step
# Epoch 136/200
# 341/341 - 1s - loss: 0.1582 - accuracy: 0.9397 - val_loss: 0.1981 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 137/200
# 341/341 - 1s - loss: 0.1568 - accuracy: 0.9384 - val_loss: 0.2079 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 138/200
# 341/341 - 1s - loss: 0.1552 - accuracy: 0.9396 - val_loss: 0.1992 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 139/200
# 341/341 - 1s - loss: 0.1568 - accuracy: 0.9396 - val_loss: 0.1989 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# Epoch 140/200
# 341/341 - 1s - loss: 0.1516 - accuracy: 0.9418 - val_loss: 0.2033 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 141/200
# 341/341 - 1s - loss: 0.1530 - accuracy: 0.9415 - val_loss: 0.1978 - val_accuracy: 0.9269 - 1s/epoch - 4ms/step
# Epoch 142/200
# 341/341 - 2s - loss: 0.1536 - accuracy: 0.9410 - val_loss: 0.2037 - val_accuracy: 0.9269 - 2s/epoch - 5ms/step
# Epoch 143/200
# 341/341 - 1s - loss: 0.1560 - accuracy: 0.9400 - val_loss: 0.2021 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 144/200
# 341/341 - 1s - loss: 0.1530 - accuracy: 0.9401 - val_loss: 0.2018 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 145/200
# 341/341 - 1s - loss: 0.1490 - accuracy: 0.9425 - val_loss: 0.2031 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 146/200
# 341/341 - 1s - loss: 0.1510 - accuracy: 0.9413 - val_loss: 0.1983 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 147/200
# 341/341 - 1s - loss: 0.1509 - accuracy: 0.9436 - val_loss: 0.2041 - val_accuracy: 0.9277 - 1s/epoch - 3ms/step
# Epoch 148/200
# 341/341 - 1s - loss: 0.1521 - accuracy: 0.9409 - val_loss: 0.2014 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 149/200
# 341/341 - 1s - loss: 0.1513 - accuracy: 0.9393 - val_loss: 0.2118 - val_accuracy: 0.9254 - 1s/epoch - 4ms/step
# Epoch 150/200
# 341/341 - 1s - loss: 0.1499 - accuracy: 0.9413 - val_loss: 0.2069 - val_accuracy: 0.9262 - 1s/epoch - 3ms/step
# Epoch 151/200
# 341/341 - 1s - loss: 0.1550 - accuracy: 0.9409 - val_loss: 0.2016 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# Epoch 152/200
# 341/341 - 1s - loss: 0.1527 - accuracy: 0.9401 - val_loss: 0.2021 - val_accuracy: 0.9306 - 1s/epoch - 4ms/step
# Epoch 153/200
# 341/341 - 1s - loss: 0.1511 - accuracy: 0.9408 - val_loss: 0.2047 - val_accuracy: 0.9277 - 1s/epoch - 4ms/step
# Epoch 154/200
# 341/341 - 1s - loss: 0.1514 - accuracy: 0.9389 - val_loss: 0.2053 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 155/200
# 341/341 - 1s - loss: 0.1538 - accuracy: 0.9404 - val_loss: 0.1980 - val_accuracy: 0.9262 - 1s/epoch - 4ms/step
# Epoch 156/200
# 341/341 - 1s - loss: 0.1535 - accuracy: 0.9394 - val_loss: 0.1988 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 157/200
# 341/341 - 1s - loss: 0.1501 - accuracy: 0.9420 - val_loss: 0.1993 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 158/200
# 341/341 - 1s - loss: 0.1529 - accuracy: 0.9403 - val_loss: 0.2078 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 159/200
# 341/341 - 1s - loss: 0.1522 - accuracy: 0.9420 - val_loss: 0.1984 - val_accuracy: 0.9321 - 1s/epoch - 3ms/step
# Epoch 160/200
# 341/341 - 1s - loss: 0.1524 - accuracy: 0.9405 - val_loss: 0.2071 - val_accuracy: 0.9269 - 1s/epoch - 3ms/step
# Epoch 161/200
# 341/341 - 1s - loss: 0.1526 - accuracy: 0.9405 - val_loss: 0.2057 - val_accuracy: 0.9310 - 1s/epoch - 3ms/step
# Epoch 162/200
# 341/341 - 1s - loss: 0.1494 - accuracy: 0.9427 - val_loss: 0.2020 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 163/200
# 341/341 - 2s - loss: 0.1478 - accuracy: 0.9407 - val_loss: 0.2004 - val_accuracy: 0.9299 - 2s/epoch - 4ms/step
# Epoch 164/200
# 341/341 - 1s - loss: 0.1535 - accuracy: 0.9416 - val_loss: 0.1993 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 165/200
# 341/341 - 1s - loss: 0.1523 - accuracy: 0.9404 - val_loss: 0.2119 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 166/200
# 341/341 - 1s - loss: 0.1508 - accuracy: 0.9438 - val_loss: 0.2092 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 167/200
# 341/341 - 1s - loss: 0.1496 - accuracy: 0.9404 - val_loss: 0.2066 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 168/200
# 341/341 - 1s - loss: 0.1520 - accuracy: 0.9407 - val_loss: 0.2055 - val_accuracy: 0.9266 - 1s/epoch - 3ms/step
# Epoch 169/200
# 341/341 - 1s - loss: 0.1521 - accuracy: 0.9407 - val_loss: 0.2017 - val_accuracy: 0.9302 - 1s/epoch - 3ms/step
# Epoch 170/200
# 341/341 - 1s - loss: 0.1506 - accuracy: 0.9419 - val_loss: 0.2059 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 171/200
# 341/341 - 1s - loss: 0.1487 - accuracy: 0.9432 - val_loss: 0.1977 - val_accuracy: 0.9328 - 1s/epoch - 3ms/step
# Epoch 172/200
# 341/341 - 1s - loss: 0.1508 - accuracy: 0.9397 - val_loss: 0.2085 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 173/200
# 341/341 - 1s - loss: 0.1494 - accuracy: 0.9426 - val_loss: 0.2063 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 174/200
# 341/341 - 2s - loss: 0.1446 - accuracy: 0.9440 - val_loss: 0.2041 - val_accuracy: 0.9317 - 2s/epoch - 4ms/step
# Epoch 175/200
# 341/341 - 1s - loss: 0.1508 - accuracy: 0.9407 - val_loss: 0.2044 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 176/200
# 341/341 - 1s - loss: 0.1479 - accuracy: 0.9419 - val_loss: 0.2063 - val_accuracy: 0.9291 - 1s/epoch - 3ms/step
# Epoch 177/200
# 341/341 - 1s - loss: 0.1495 - accuracy: 0.9420 - val_loss: 0.2001 - val_accuracy: 0.9284 - 1s/epoch - 3ms/step
# Epoch 178/200
# 341/341 - 1s - loss: 0.1494 - accuracy: 0.9408 - val_loss: 0.2086 - val_accuracy: 0.9310 - 1s/epoch - 4ms/step
# Epoch 179/200
# 341/341 - 1s - loss: 0.1487 - accuracy: 0.9415 - val_loss: 0.2044 - val_accuracy: 0.9324 - 1s/epoch - 3ms/step
# Epoch 180/200
# 341/341 - 1s - loss: 0.1452 - accuracy: 0.9430 - val_loss: 0.2051 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 181/200
# 341/341 - 1s - loss: 0.1502 - accuracy: 0.9420 - val_loss: 0.2088 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 182/200
# 341/341 - 1s - loss: 0.1480 - accuracy: 0.9420 - val_loss: 0.2106 - val_accuracy: 0.9295 - 1s/epoch - 4ms/step
# Epoch 183/200
# 341/341 - 1s - loss: 0.1468 - accuracy: 0.9417 - val_loss: 0.2057 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 184/200
# 341/341 - 1s - loss: 0.1460 - accuracy: 0.9430 - val_loss: 0.2013 - val_accuracy: 0.9317 - 1s/epoch - 4ms/step
# Epoch 185/200
# 341/341 - 1s - loss: 0.1471 - accuracy: 0.9421 - val_loss: 0.2069 - val_accuracy: 0.9288 - 1s/epoch - 4ms/step
# Epoch 186/200
# 341/341 - 1s - loss: 0.1517 - accuracy: 0.9394 - val_loss: 0.2081 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 187/200
# 341/341 - 1s - loss: 0.1467 - accuracy: 0.9431 - val_loss: 0.2049 - val_accuracy: 0.9295 - 1s/epoch - 3ms/step
# Epoch 188/200
# 341/341 - 1s - loss: 0.1457 - accuracy: 0.9425 - val_loss: 0.2057 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 189/200
# 341/341 - 1s - loss: 0.1489 - accuracy: 0.9426 - val_loss: 0.2097 - val_accuracy: 0.9273 - 1s/epoch - 3ms/step
# Epoch 190/200
# 341/341 - 1s - loss: 0.1498 - accuracy: 0.9402 - val_loss: 0.2104 - val_accuracy: 0.9335 - 1s/epoch - 3ms/step
# Epoch 191/200
# 341/341 - 1s - loss: 0.1483 - accuracy: 0.9436 - val_loss: 0.2028 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 192/200
# 341/341 - 1s - loss: 0.1437 - accuracy: 0.9441 - val_loss: 0.2124 - val_accuracy: 0.9299 - 1s/epoch - 3ms/step
# Epoch 193/200
# 341/341 - 1s - loss: 0.1492 - accuracy: 0.9429 - val_loss: 0.2049 - val_accuracy: 0.9288 - 1s/epoch - 3ms/step
# Epoch 194/200
# 341/341 - 1s - loss: 0.1473 - accuracy: 0.9424 - val_loss: 0.2090 - val_accuracy: 0.9317 - 1s/epoch - 3ms/step
# Epoch 195/200
# 341/341 - 1s - loss: 0.1457 - accuracy: 0.9434 - val_loss: 0.2082 - val_accuracy: 0.9280 - 1s/epoch - 4ms/step
# Epoch 196/200
# 341/341 - 1s - loss: 0.1403 - accuracy: 0.9458 - val_loss: 0.2020 - val_accuracy: 0.9306 - 1s/epoch - 4ms/step
# Epoch 197/200
# 341/341 - 1s - loss: 0.1448 - accuracy: 0.9443 - val_loss: 0.2050 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 198/200
# 341/341 - 1s - loss: 0.1432 - accuracy: 0.9420 - val_loss: 0.2081 - val_accuracy: 0.9280 - 1s/epoch - 3ms/step
# Epoch 199/200
# 341/341 - 1s - loss: 0.1421 - accuracy: 0.9450 - val_loss: 0.2108 - val_accuracy: 0.9254 - 1s/epoch - 3ms/step
# Epoch 200/200
# 341/341 - 1s - loss: 0.1435 - accuracy: 0.9437 - val_loss: 0.2114 - val_accuracy: 0.9306 - 1s/epoch - 3ms/step
# ********************************************************
# 86/86 [==============================] - 0s 1ms/step
# Testing ANN Accuracy:  0.9305912596401028
# 341/341 [==============================] - 1s 2ms/step
# Training ANN Accuracy:  0.9536186627479795
